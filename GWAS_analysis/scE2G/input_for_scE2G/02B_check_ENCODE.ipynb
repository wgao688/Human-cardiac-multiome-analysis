# %% [markdown]
# ### Check that the obs_names are the same for ATAC and RNA

# %%
import scanpy as sc

# %%
# %%time
ATAC_adata = sc.read_h5ad("01_filtered_ENCODE_multiome_ATAC_adata.h5ad")
ATAC_adata
# Out:
# CPU times: user 8.02 s, sys: 37.9 s, total: 45.9 s
# Wall time: 54.7 s
# AnnData object with n_obs × n_vars = 287596 × 606219
#     obs: 'barcode', 'ATAC_barcode', 'sample_id', 'leiden', 'donor_id', 'study', 'age_status', 'age', 'sex', 'region', 'disease_binary', 'technology', 'fragment_file', 'full_path', 'file', 'nfrag', 'tsse', 'cell_type', 'tech_plus_study', 'RNA_barcode', 'multiome_barcode'
#     var: 'count', 'selected'
#     uns: 'AnnDataSet', 'macs3', 'reference_sequences', 'spectral_eigenvalue'
#     obsm: 'X_spectral', 'X_spectral_harmony', 'X_umap', 'fragment_paired'
#     obsp: 'distances'

# %%
# %%time
RNA_adata = sc.read_h5ad("01_filtered_ENCODE_multiome_RNA_adata.h5ad")
RNA_adata
# Out:
# CPU times: user 1.98 s, sys: 9.13 s, total: 11.1 s
# Wall time: 12.4 s
# AnnData object with n_obs × n_vars = 287596 × 16115
#     obs: 'age', 'donor_id', 'sex', 'region', 'cell_type', 'disease', 'consistent_cell_type', 'study', 'technology', 'cell_or_nuclei', 'barcode', 'sample_id', 'age_status', 'tech_plus_study', 'disease_binary', 'decade', 'age_group', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'scvi_cell_type', 'redo_leiden_0.5', 'UMAP1', 'UMAP2', 'v2_scvi_cell_type', 'final_cell_type', 'multiome_barcode'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#     layers: 'counts'

# %% [markdown]
# Confirm that all obs_names are the same

# %%
len(set(RNA_adata.obs_names) & set(ATAC_adata.obs_names))
# Out:
# 287596

# %%
len(set(RNA_adata.obs_names) - set(ATAC_adata.obs_names))
# Out:
# 0

# %%
len(set(ATAC_adata.obs_names) - set(RNA_adata.obs_names))
# Out:
# 0
