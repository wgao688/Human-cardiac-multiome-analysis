# %%
#### https://stephenturner.github.io/kgp/
install.packages("kgp")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# install.packages("devtools")
devtools::install_github("stephenturner/kgp")
# Out:
# ...
# ── R CMD build ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/mnt/data1/william/tmp/RtmpHdwR5S/remotes318a3d344f9e9c/stephenturner-kgp-2848553/DESCRIPTION’
# ─  preparing ‘kgp’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘kgp_1.1.1.tar.gz’

# %%
library(kgp)
data(kgp)

# %%
table(kgpe$reg)
# Out:
# AFR AMR EAS EUR SAS
# 893 490 585 633 601

# %%
European_donors <- kgpe[kgpe$reg == "EUR", ]$fid

# %%
writeLines(European_donors, con = "1K_genomes_eur_samples.txt")
