# %% [markdown]
# ### Convert the files downloaded from Broad Single Cell Portal to an adata format
# #### Filter to just LV cells

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import os
from collections import Counter
import re
import scanpy.external as sce

# %% [markdown]
# ### Load in the count matrix
# This will take a few minutes to load

# %%
# %%time
# Load the count matrix, need to perform transpose
adata = sc.read_mtx('AllNuclei_snRNA_counts.mtx').T
# Out:
# CPU times: user 8min 22s, sys: 16.1 s, total: 8min 38s
# Wall time: 8min 37s

# %%
adata.layers["counts"] = adata.X
adata.layers["counts"].sum(axis = 1)
# Out:
# matrix([[24524.],
#         [ 8037.],
#         [ 5459.],
#         ...,
#         [ 4586.],
#         [ 4651.],
#         [ 3079.]], dtype=float32)

# %%
# Load the genes/features
genes = pd.read_csv('AllNuclei_snRNA_counts_rownames.txt', header=None, sep='\t')
adata.var_names = genes[0].values

# %%
# Load the barcodes/cell names
barcodes = pd.read_csv('AllNuclei_snRNA_counts_colnames.txt', header=None, sep='\t')
adata.obs_names = barcodes[0].values

# %%
metadata = pd.read_csv('AllNuclei_snRNA_metadata.csv', skiprows = [1])
metadata.head()
adata.obs = metadata

# %%
adata.obs
# Out:
#                                NAME orig_ident  nCount_RNA  nFeature_RNA  \
# 0           P8_1_AAGCCATGTCGGCTAC-1       P8_1       24524          7957
# 1          P40_2_GTTGTGAAGCGCCATC-1      P40_2        8037          3749
# 2          P26_1_AGTGCCGAGATAACGT-1      P26_1        5459          3252
# 3          P26_1_TCGCACTCATATCGGT-1      P26_1        6277          3356
# 4           P8_2_CTAGACATCCCATACC-1       P8_2       21356          7881
# ...                             ...        ...         ...           ...
# 157288  RV_198_2_ATTCTTGCATCTCCCA-1   RV_198_2        5004          2177
# 157289  RV_198_2_CAAGACTGTAATACCC-1   RV_198_2        4733          2048
# 157290  RV_198_2_AGTTCGAAGTGCGTCC-1   RV_198_2        4586          1844
# 157291  RV_198_1_GTCGTAACACAAGCCC-1   RV_198_1        4651          1999
# 157292  RV_198_1_ATCGTGAAGGTCATAA-1   RV_198_1        3079          1333
#
#          labID                procedure        age gender    echoEF vers10X  \
# 0           P8  Redo_Sternomoty_Norwood   0y_2m_3d      M      P8_1      v3
# 1          P40         Heart_Transplant  4y_4m_20d      M     P40_2      v3
# 2          P26                TOF_Repai   0y_3m_3d      M     P26_1      v3
# 3          P26                TOF_Repai   0y_3m_3d      M     P26_1      v3
# 4           P8  Redo_Sternomoty_Norwood   0y_2m_3d      M      P8_2      v3
# ...        ...                      ...        ...    ...       ...     ...
# 157288  13_198                      NaN        11y      M  RV_198_2      v3
# 157289  13_198                      NaN        11y      M  RV_198_2      v3
# 157290  13_198                      NaN        11y      M  RV_198_2      v3
# 157291  13_198                      NaN        11y      M  RV_198_1      v3
# 157292  13_198                      NaN        11y      M  RV_198_1      v3
#
#         ...   donor_id         species species__ontology_label        disease  \
# 0       ...         P8  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 1       ...        P40  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 2       ...        P26  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 3       ...        P26  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 4       ...         P8  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# ...     ...        ...             ...                     ...            ...
# 157288  ...  13_198_RV  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 157289  ...  13_198_RV  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 157290  ...  13_198_RV  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 157291  ...  13_198_RV  NCBITaxon_9606            Homo sapiens  MONDO_0005453
# 157292  ...  13_198_RV  NCBITaxon_9606            Homo sapiens  MONDO_0005453
#
#          disease__ontology_label           organ organ__ontology_label  \
# 0       congenital heart disease  UBERON_0000948                 heart
# 1       congenital heart disease  UBERON_0000948                 heart
# 2       congenital heart disease  UBERON_0000948                 heart
# 3       congenital heart disease  UBERON_0000948                 heart
# 4       congenital heart disease  UBERON_0000948                 heart
# ...                          ...             ...                   ...
# 157288  congenital heart disease  UBERON_0000948                 heart
# 157289  congenital heart disease  UBERON_0000948                 heart
# 157290  congenital heart disease  UBERON_0000948                 heart
# 157291  congenital heart disease  UBERON_0000948                 heart
# 157292  congenital heart disease  UBERON_0000948                 heart
#
#        library_preparation_protocol   sex  \
# 0                       EFO_0009922  male
# 1                       EFO_0009922  male
# 2                       EFO_0009922  male
# 3                       EFO_0009922  male
# 4                       EFO_0009922  male
# ...                             ...   ...
# 157288                  EFO_0009922  male
# 157289                  EFO_0009922  male
# 157290                  EFO_0009922  male
# 157291                  EFO_0009922  male
# 157292                  EFO_0009922  male
#
#        library_preparation_protocol__ontology_label
# 0                                         10x 3' v3
# 1                                         10x 3' v3
# 2                                         10x 3' v3
# 3                                         10x 3' v3
# 4                                         10x 3' v3
# ...                                             ...
# 157288                                    10x 3' v3
# 157289                                    10x 3' v3
# 157290                                    10x 3' v3
# 157291                                    10x 3' v3
# 157292                                    10x 3' v3
#
# [157293 rows x 35 columns]

# %%
adata.obs_names = adata.obs['NAME']
adata.obs = adata.obs.drop(columns = "NAME")

# %%
# all of the obs_names are unique
Counter(adata.obs_names).most_common()[0]
# Out:
# ('P8_1_AAGCCATGTCGGCTAC-1', 1)

# %% [markdown]
# #### Remove the RV samples

# %%
sum(adata.obs_names.str.startswith("RV_"))
# Out:
# 23733

# %%
adata = adata[~adata.obs_names.str.startswith("RV_"), :]

# %%
adata.write("01_Hill_LV_adata.h5ad")
