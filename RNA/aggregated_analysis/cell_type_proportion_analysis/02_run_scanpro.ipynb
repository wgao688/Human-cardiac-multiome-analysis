# %% [markdown]
# #### Run scanpro as a nice python implementation of propeller, save the results for plotting in the next script `03_produce_cell_type_proportion_plots.ipynb`

# %%
from scanpro import scanpro
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter

# %%
results_dir = "scanpro_results_dir/"
os.makedirs(results_dir, exist_ok=True)

# %%
# %%time
adata = sc.read_h5ad("../07_final_RNA_without_scvi.h5ad")
adata
# Out:
# CPU times: user 13.6 s, sys: 1min 7s, total: 1min 21s
# Wall time: 1min 21s
# AnnData object with n_obs × n_vars = 2305964 × 16115
#     obs: 'age', 'donor_id', 'sex', 'region', 'cell_type', 'disease', 'consistent_cell_type', 'study', 'technology', 'cell_or_nuclei', 'barcode', 'sample_id', 'age_status', 'tech_plus_study', 'disease_binary', 'decade', 'age_group', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'scvi_cell_type', 'redo_leiden_0.5', 'UMAP1', 'UMAP2', 'v2_scvi_cell_type', 'final_cell_type'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#     layers: 'counts'

# %% [markdown]
# ### Determine number of nuclei per donor, remove those without more than 1K nuclei

# %%
counts_per_nuclei = adata.obs.groupby('donor_id').count()[['age']].rename(columns = {'age': 'count'}).reset_index()

# %%
print(f"Number of total donors: {len(counts_per_nuclei.donor_id.unique())}")
# Out:
# Number of total donors: 299

# %%
nuclei_threshold = 1000
donors_to_keep = counts_per_nuclei[counts_per_nuclei['count'] > nuclei_threshold].donor_id

# %%
filtered_adata = adata[adata.obs.donor_id.isin(donors_to_keep)]
num_donors = len(filtered_adata.obs.donor_id.unique())
print(f"Number of total donors after filtering: {num_donors}")
# Out:
# Number of total donors after filtering: 292

# %%
filtered_adata.obs.columns
# Out:
# Index(['age', 'donor_id', 'sex', 'region', 'cell_type', 'disease',
#        'consistent_cell_type', 'study', 'technology', 'cell_or_nuclei',
#        'barcode', 'sample_id', 'age_status', 'tech_plus_study',
#        'disease_binary', 'decade', 'age_group', '_scvi_batch', '_scvi_labels',
#        'leiden_scVI', 'scvi_cell_type', 'redo_leiden_0.5', 'UMAP1', 'UMAP2',
#        'v2_scvi_cell_type', 'final_cell_type'],
#       dtype='object')

# %%
filtered_adata.obs.disease_binary.unique()
# Out:
# ['N', 'Y']
# Categories (2, object): ['N', 'Y']

# %%
filtered_adata.obs.age_group.unique()
# Out:
# ['fetal', 'old', 'middle', 'young']
# Categories (4, object): ['fetal', 'middle', 'old', 'young']

# %% [markdown]
# ### Perform disease and age related analysis
#
# #### To do this, filter to just the postnatal data

# %%
non_fetal_adata = filtered_adata[filtered_adata.obs.age_group != "fetal", :]
num_donors = len(non_fetal_adata.obs.donor_id.unique())
print(f"Number of non-fetal donors: {num_donors}")
# Out:
# Number of non-fetal donors: 279

# %% [markdown]
# #### Perform analysis focused on age_group

# %%
out = scanpro(non_fetal_adata, clusters_col='final_cell_type', 
              conds_col='age_group', samples_col='donor_id', 
              covariates=['disease_binary', 'sex', 'tech_plus_study'], transform="arcsin")

non_fetal_age_group_results_df = out.results
non_fetal_age_group_results_df
# Out:
# [INFO] There are more than 2 conditions. ANOVA will be performed...
# [INFO] Done!
#                baseline_props  mean_props_old  mean_props_middle  \
# clusters
# Adipocyte            0.005411        0.006875           0.005385
# Cardiomyocyte        0.292212        0.249498           0.286405
# Endocardial          0.015946        0.017433           0.017308
# Endothelial          0.139881        0.133678           0.131475
# Epicardial           0.003912        0.011209           0.002427
# Fibroblast           0.236539        0.256185           0.230033
# LEC                  0.005776        0.007132           0.007608
# Lymphoid             0.029115        0.036557           0.029105
# Mast                 0.003981        0.003053           0.004419
# Myeloid              0.106990        0.120511           0.111215
# Neuronal             0.009592        0.008983           0.009353
# Pericyte             0.124728        0.123171           0.137313
# vSMC                 0.025918        0.025716           0.027955
#
#                mean_props_young  f_statistics  p_values  adjusted_p_values
# clusters
# Adipocyte              0.004197      0.662804  0.516245           0.559266
# Cardiomyocyte          0.302098      1.527865  0.218878           0.355677
# Endocardial            0.022682      0.429799  0.651087           0.651087
# Endothelial            0.162958      1.858238  0.157946           0.324117
# Epicardial             0.000951      2.504586  0.083616           0.266599
# Fibroblast             0.221655      2.968938  0.053046           0.266599
# LEC                    0.003926      1.061833  0.347268           0.455997
# Lymphoid               0.025979      2.494865  0.084418           0.266599
# Mast                   0.003231      1.757085  0.174525           0.324117
# Myeloid                0.102704      2.329377  0.099320           0.266599
# Neuronal               0.011538      0.789877  0.454952           0.537671
# Pericyte               0.115908      2.296944  0.102538           0.266599
# vSMC                   0.022173      1.051731  0.350767           0.455997

# %%
non_fetal_age_group_results_df.to_csv(results_dir + "age_group_scanpro_results.csv")

# %%
non_fetal_age_group_results_df
non_fetal_age_group_results_df[non_fetal_age_group_results_df['adjusted_p_values'] < 0.05]
# Out:
# Empty DataFrame
# Columns: [baseline_props, mean_props_old, mean_props_middle, mean_props_young, f_statistics, p_values, adjusted_p_values]
# Index: []

# %% [markdown]
# #### Perform analysis focused on disease

# %%
out = scanpro(non_fetal_adata, clusters_col = 'final_cell_type', 
              conds_col='disease_binary', samples_col='donor_id', 
              covariates=['age_group', 'sex', 'tech_plus_study'], transform="arcsin")

disease_status_results_df = out.results
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!

# %%
disease_status_results_df
# Out:
#                baseline_props  mean_props_Y  mean_props_N  prop_ratio  \
# clusters
# Adipocyte            0.005411      0.004297      0.006796    0.632315
# Cardiomyocyte        0.292212      0.249562      0.300341    0.830928
# Endocardial          0.015946      0.013399      0.022730    0.589477
# Endothelial          0.139881      0.181050      0.102721    1.762537
# Epicardial           0.003912      0.007221      0.003331    2.167691
# Fibroblast           0.236539      0.225313      0.247326    0.910996
# LEC                  0.005776      0.008714      0.004981    1.749345
# Lymphoid             0.029115      0.035356      0.027314    1.294402
# Mast                 0.003981      0.002081      0.005092    0.408754
# Myeloid              0.106990      0.099089      0.124130    0.798271
# Neuronal             0.009592      0.009670      0.009676    0.999355
# Pericyte             0.124728      0.131442      0.125312    1.048921
# vSMC                 0.025918      0.032807      0.020251    1.620058
#
#                t_statistics      p_values  adjusted_p_values
# clusters
# Adipocyte          0.029597  9.764110e-01       9.764110e-01
# Cardiomyocyte     -5.310456  2.311943e-07       1.502763e-06
# Endocardial       -1.602456  1.102426e-01       1.577002e-01
# Endothelial        3.959885  9.634199e-05       2.504892e-04
# Epicardial         3.010550  2.858576e-03       4.645186e-03
# Fibroblast         1.554279  1.213078e-01       1.577002e-01
# LEC                4.877336  1.853793e-06       8.033104e-06
# Lymphoid           3.504948  5.358041e-04       1.160909e-03
# Mast              -4.423857  1.415397e-05       4.600040e-05
# Myeloid            1.224000  2.220362e-01       2.624064e-01
# Neuronal          -0.649262  5.167295e-01       5.597903e-01
# Pericyte          -3.368283  8.683818e-04       1.612709e-03
# vSMC               6.237148  1.746174e-09       2.270026e-08

# %%
disease_status_results_df[disease_status_results_df['adjusted_p_values'] < 0.05]
# Out:
#                baseline_props  mean_props_Y  mean_props_N  prop_ratio  \
# clusters
# Cardiomyocyte        0.292212      0.249562      0.300341    0.830928
# Endothelial          0.139881      0.181050      0.102721    1.762537
# Epicardial           0.003912      0.007221      0.003331    2.167691
# LEC                  0.005776      0.008714      0.004981    1.749345
# Lymphoid             0.029115      0.035356      0.027314    1.294402
# Mast                 0.003981      0.002081      0.005092    0.408754
# Pericyte             0.124728      0.131442      0.125312    1.048921
# vSMC                 0.025918      0.032807      0.020251    1.620058
#
#                t_statistics      p_values  adjusted_p_values
# clusters
# Cardiomyocyte     -5.310456  2.311943e-07       1.502763e-06
# Endothelial        3.959885  9.634199e-05       2.504892e-04
# Epicardial         3.010550  2.858576e-03       4.645186e-03
# LEC                4.877336  1.853793e-06       8.033104e-06
# Lymphoid           3.504948  5.358041e-04       1.160909e-03
# Mast              -4.423857  1.415397e-05       4.600040e-05
# Pericyte          -3.368283  8.683818e-04       1.612709e-03
# vSMC               6.237148  1.746174e-09       2.270026e-08

# %%
disease_status_results_df.to_csv(results_dir + "disease_scanpro_results.csv")

# %% [markdown]
# ### Perform analysis based on sex

# %%
out = scanpro(non_fetal_adata, clusters_col='final_cell_type', 
              conds_col='sex', samples_col='donor_id', 
              covariates=['age_group', 'disease_binary', 'tech_plus_study'], transform="arcsin")
sex_results_df = out.results
sex_results_df
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!
#                baseline_props  mean_props_male  mean_props_female  prop_ratio  \
# clusters
# Adipocyte            0.005411         0.005590           0.005755    0.971300
# Cardiomyocyte        0.292212         0.255364           0.315252    0.810033
# Endocardial          0.015946         0.015958           0.022838    0.698773
# Endothelial          0.139881         0.141848           0.133033    1.066261
# Epicardial           0.003912         0.006567           0.002558    2.567672
# Fibroblast           0.236539         0.251984           0.211218    1.193003
# LEC                  0.005776         0.005338           0.009082    0.587841
# Lymphoid             0.029115         0.029977           0.032813    0.913562
# Mast                 0.003981         0.003493           0.004095    0.853122
# Myeloid              0.106990         0.115031           0.108430    1.060881
# Neuronal             0.009592         0.009913           0.009250    1.071637
# Pericyte             0.124728         0.132405           0.120581    1.098060
# vSMC                 0.025918         0.026531           0.025096    1.057161
#
#                t_statistics  p_values  adjusted_p_values
# clusters
# Adipocyte         -1.009978  0.313424           0.549344
# Cardiomyocyte     -2.135835  0.033607           0.145629
# Endocardial       -1.383531  0.167663           0.435923
# Endothelial       -0.187942  0.851065           0.921987
# Epicardial        -0.283689  0.776870           0.918119
# Fibroblast         3.339102  0.000961           0.012490
# LEC               -2.490385  0.013372           0.086916
# Lymphoid          -1.212700  0.226321           0.490363
# Mast              -0.369597  0.711977           0.918119
# Myeloid            0.740653  0.459558           0.663806
# Neuronal          -0.068535  0.945411           0.945411
# Pericyte           1.884417  0.060600           0.196949
# vSMC               0.959741  0.338058           0.549344

# %%
sex_results_df[sex_results_df['adjusted_p_values'] < 0.05]
# Out:
#             baseline_props  mean_props_male  mean_props_female  prop_ratio  \
# clusters
# Fibroblast        0.236539         0.251984           0.211218    1.193003
#
#             t_statistics  p_values  adjusted_p_values
# clusters
# Fibroblast      3.339102  0.000961            0.01249

# %%
sex_results_df.to_csv(results_dir + "sex_scanpro_results.csv")

# %% [markdown]
# ### Fetal vs. young

# %%
fetal_young_adata =  ( filtered_adata[(filtered_adata.obs.age_group.isin(["fetal", "young"])) & 
                      (filtered_adata.obs.disease_binary == "N"), :] )
fetal_young_adata
num_donors = len(fetal_young_adata.obs.donor_id.unique())

print(f"Number of fetal + young non-diseased donors: {num_donors}")
# Out:
# Number of fetal + young non-diseased donors: 42

# %%
out = scanpro(fetal_young_adata, clusters_col='final_cell_type', 
              conds_col='age_group', samples_col='donor_id', 
              covariates=['sex', 'disease_binary', 'tech_plus_study'], transform="arcsin")
fetal_results_df = out.results
# Out:
# [INFO] There are 2 conditions. T-Test will be performed...
# [INFO] Done!

# %%
fetal_results_df[fetal_results_df['adjusted_p_values'] < 0.05]
# Out:
#                baseline_props  mean_props_fetal  mean_props_young  prop_ratio  \
# clusters
# Adipocyte            0.004763          0.000033          0.006825    0.004869
# Cardiomyocyte        0.313055          0.379948          0.282319    1.345810
# Endocardial          0.044097          0.073538          0.028796    2.553783
# Epicardial           0.010494          0.019459          0.000880   22.103201
# LEC                  0.005600          0.008553          0.003605    2.372401
# Mast                 0.004385          0.001154          0.005597    0.206168
# Myeloid              0.104578          0.029864          0.128352    0.232671
# Pericyte             0.091981          0.049726          0.111475    0.446076
#
#                t_statistics      p_values  adjusted_p_values
# clusters
# Adipocyte         -2.612991  1.309829e-02           0.024325
# Cardiomyocyte      2.480335  1.803466e-02           0.029306
# Endocardial        2.901315  6.358206e-03           0.013776
# Epicardial         4.399723  9.536322e-05           0.000579
# LEC                3.881913  4.341168e-04           0.001411
# Mast              -3.034535  4.499907e-03           0.011700
# Myeloid           -6.077779  5.885822e-07           0.000008
# Pericyte          -4.285766  1.336553e-04           0.000579

# %%
fetal_results_df.to_csv(results_dir + "fetal_scanpro_results.csv")

# %% [markdown]
# ### Produce plots of proportions using tidy version of data

# %%
adata_metadata = adata.obs
cell_type_key = "final_cell_type"
donor_level_metadata = adata_metadata[["sex", "age", "age_group",
                                     "donor_id", "disease_binary", 
                                       "tech_plus_study"]].drop_duplicates().reset_index(drop = True)

cell_type_counts_per_donor = pd.crosstab(adata_metadata['donor_id'], adata_metadata[cell_type_key])
norm_filtered_cell_counts_df = 100 * cell_type_counts_per_donor.div(cell_type_counts_per_donor.sum(axis = 1), axis = 0)

# %%
prop_long_df = norm_filtered_cell_counts_df.reset_index().melt(id_vars = 'donor_id', 
                                                               var_name = 'cell_type', 
                                                               value_name = 'proportion').reset_index(drop = True)
prop_long_df.head()

# merge with metadata so that we have the covariates for regression
prop_long_df = prop_long_df.merge(donor_level_metadata, on = "donor_id", how = "inner")

# %%
prop_long_df
# Out:
#                  donor_id      cell_type  proportion   sex   age age_group  \
# 0      Chaffin 2022:P1290      Adipocyte    0.000000  male  65.0       old
# 1      Chaffin 2022:P1290  Cardiomyocyte   38.080942  male  65.0       old
# 2      Chaffin 2022:P1290    Endocardial    0.036027  male  65.0       old
# 3      Chaffin 2022:P1290    Endothelial   18.806293  male  65.0       old
# 4      Chaffin 2022:P1290     Epicardial    0.000000  male  65.0       old
# ...                   ...            ...         ...   ...   ...       ...
# 3882  Simonson 2023:P1801           Mast    0.081054  male  42.0    middle
# 3883  Simonson 2023:P1801        Myeloid    7.213779  male  42.0    middle
# 3884  Simonson 2023:P1801       Neuronal    1.215805  male  42.0    middle
# 3885  Simonson 2023:P1801       Pericyte   11.286727  male  42.0    middle
# 3886  Simonson 2023:P1801           vSMC    1.621074  male  42.0    middle
#
#      disease_binary          tech_plus_study
# 0                 Y   3prime-v3_Chaffin 2022
# 1                 Y   3prime-v3_Chaffin 2022
# 2                 Y   3prime-v3_Chaffin 2022
# 3                 Y   3prime-v3_Chaffin 2022
# 4                 Y   3prime-v3_Chaffin 2022
# ...             ...                      ...
# 3882              N  3prime-v3_Simonson 2023
# 3883              N  3prime-v3_Simonson 2023
# 3884              N  3prime-v3_Simonson 2023
# 3885              N  3prime-v3_Simonson 2023
# 3886              N  3prime-v3_Simonson 2023
#
# [3887 rows x 8 columns]
