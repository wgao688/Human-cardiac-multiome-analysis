# %% [markdown]
# ### Prepare the RNA adata for SCENIC+:
#
# - see here for example: https://scenicplus.readthedocs.io/en/latest/human_cerebellum_scRNA_pp.html
#
# Since we are interested in the development+disease contrast, we will use the cell type, disease binary, and age status like this: Cardiomyocyte:Y:postnatal and store in 'updated_cell_type'

# %%
import scanpy as sc 
import pandas as pd
import numpy as np
from collections import Counter

# %%
adata = sc.read_h5ad("01_subsampled_RNA.h5ad")
adata.obs_names_make_unique()

# %%
adata.obs
# Out:
#                                age                              donor_id  \
# ENCSR755CIF:ACCACACCATTCCTCG  47.0        ENCODE v4 (Snyder):ENCSR755CIF
# ENCSR398YBK:TAACCGGTCGTTACAA  48.0        ENCODE v4 (Snyder):ENCSR398YBK
# ENCSR190TRK:ACATTAGTCATGCTTT  59.0        ENCODE v4 (Snyder):ENCSR190TRK
# P1582:AGTAACCTCCACCCTA-1-60   58.0                    Chaffin 2022:P1582
# H0020_LV:ATACCGAAGAGAGCGG     42.5  Litvinukova 2020:H6-Nuclei_3prime-v3
# ...                            ...                                   ...
# ReichartH46:773447            34.5             Reichart 2022:ReichartH46
# ENCSR814LMX:GCATTGCCAGCAACAG  31.0        ENCODE v4 (Snyder):ENCSR814LMX
# ENCSR084XKX:TTGCAATCATCAGTAT  30.0        ENCODE v4 (Snyder):ENCSR084XKX
# ENCSR439ZVQ:CCGTTACTCCTCCATA  20.0        ENCODE v4 (Snyder):ENCSR439ZVQ
# TWCM-13-198:GGACATTAGAAGATTC  11.0               Koenig 2022:TWCM-13-198
#
#                                  sex region                  cell_type  \
# ENCSR755CIF:ACCACACCATTCCTCG  female     LV                       CM-1
# ENCSR398YBK:TAACCGGTCGTTACAA  female     LV                       CM-2
# ENCSR190TRK:ACATTAGTCATGCTTT  female     LV                       CM-1
# P1582:AGTAACCTCCACCCTA-1-60   female     LV            Cardiomyocyte_I
# H0020_LV:ATACCGAAGAGAGCGG     female     LV  Ventricular Cardiomyocyte
# ...                              ...    ...                        ...
# ReichartH46:773447              male     LV                 mural cell
# ENCSR814LMX:GCATTGCCAGCAACAG    male     LV                   Pericyte
# ENCSR084XKX:TTGCAATCATCAGTAT    male     LV                   Pericyte
# ENCSR439ZVQ:CCGTTACTCCTCCATA    male     LV                   Pericyte
# TWCM-13-198:GGACATTAGAAGATTC    male     LV                  Pericytes
#
#                              disease consistent_cell_type               study  \
# ENCSR755CIF:ACCACACCATTCCTCG      ND        Cardiomyocyte  ENCODE v4 (Snyder)
# ENCSR398YBK:TAACCGGTCGTTACAA      ND        Cardiomyocyte  ENCODE v4 (Snyder)
# ENCSR190TRK:ACATTAGTCATGCTTT      ND        Cardiomyocyte  ENCODE v4 (Snyder)
# P1582:AGTAACCTCCACCCTA-1-60       ND        Cardiomyocyte        Chaffin 2022
# H0020_LV:ATACCGAAGAGAGCGG         ND        Cardiomyocyte    Litvinukova 2020
# ...                              ...                  ...                 ...
# ReichartH46:773447                ND             Pericyte       Reichart 2022
# ENCSR814LMX:GCATTGCCAGCAACAG      ND             Pericyte  ENCODE v4 (Snyder)
# ENCSR084XKX:TTGCAATCATCAGTAT      ND             Pericyte  ENCODE v4 (Snyder)
# ENCSR439ZVQ:CCGTTACTCCTCCATA      ND             Pericyte  ENCODE v4 (Snyder)
# TWCM-13-198:GGACATTAGAAGATTC      ND             Pericyte         Koenig 2022
#
#                                technology cell_or_nuclei  ... _scvi_batch  \
# ENCSR755CIF:ACCACACCATTCCTCG  Multiome-v1         Nuclei  ...          10
# ENCSR398YBK:TAACCGGTCGTTACAA  Multiome-v1         Nuclei  ...          10
# ENCSR190TRK:ACATTAGTCATGCTTT  Multiome-v1         Nuclei  ...          10
# P1582:AGTAACCTCCACCCTA-1-60     3prime-v3         Nuclei  ...           2
# H0020_LV:ATACCGAAGAGAGCGG       3prime-v3         Nuclei  ...           5
# ...                                   ...            ...  ...         ...
# ReichartH46:773447              3prime-v3         Nuclei  ...           6
# ENCSR814LMX:GCATTGCCAGCAACAG  Multiome-v1         Nuclei  ...          10
# ENCSR084XKX:TTGCAATCATCAGTAT  Multiome-v1         Nuclei  ...          10
# ENCSR439ZVQ:CCGTTACTCCTCCATA  Multiome-v1         Nuclei  ...          10
# TWCM-13-198:GGACATTAGAAGATTC    5prime-v1         Nuclei  ...           8
#
#                              _scvi_labels leiden_scVI scvi_cell_type  \
# ENCSR755CIF:ACCACACCATTCCTCG            0           1  Cardiomyocyte
# ENCSR398YBK:TAACCGGTCGTTACAA            0           1  Cardiomyocyte
# ENCSR190TRK:ACATTAGTCATGCTTT            0          11  Cardiomyocyte
# P1582:AGTAACCTCCACCCTA-1-60             0           1  Cardiomyocyte
# H0020_LV:ATACCGAAGAGAGCGG               0           1  Cardiomyocyte
# ...                                   ...         ...            ...
# ReichartH46:773447                      0           9       Pericyte
# ENCSR814LMX:GCATTGCCAGCAACAG            0           9       Pericyte
# ENCSR084XKX:TTGCAATCATCAGTAT            0           9       Pericyte
# ENCSR439ZVQ:CCGTTACTCCTCCATA            0           9       Pericyte
# TWCM-13-198:GGACATTAGAAGATTC            0           9       Pericyte
#
#                              redo_leiden_0.5      UMAP1     UMAP2  \
# ENCSR755CIF:ACCACACCATTCCTCG               5  12.305471  1.072475
# ENCSR398YBK:TAACCGGTCGTTACAA               9  12.491392  2.655510
# ENCSR190TRK:ACATTAGTCATGCTTT               6  16.135275  1.360960
# P1582:AGTAACCTCCACCCTA-1-60                4  14.531496  0.243661
# H0020_LV:ATACCGAAGAGAGCGG                  3  10.863509  2.470121
# ...                                      ...        ...       ...
# ReichartH46:773447                         0   0.879716 -7.030258
# ENCSR814LMX:GCATTGCCAGCAACAG               0   2.356153 -4.613572
# ENCSR084XKX:TTGCAATCATCAGTAT               6   3.749553 -4.662053
# ENCSR439ZVQ:CCGTTACTCCTCCATA               1   3.987428 -6.293432
# TWCM-13-198:GGACATTAGAAGATTC               0   2.804775 -5.088640
#
#                               v2_scvi_cell_type  final_cell_type  \
# ENCSR755CIF:ACCACACCATTCCTCG      Cardiomyocyte    Cardiomyocyte
# ENCSR398YBK:TAACCGGTCGTTACAA      Cardiomyocyte    Cardiomyocyte
# ENCSR190TRK:ACATTAGTCATGCTTT      Cardiomyocyte    Cardiomyocyte
# P1582:AGTAACCTCCACCCTA-1-60       Cardiomyocyte    Cardiomyocyte
# H0020_LV:ATACCGAAGAGAGCGG         Cardiomyocyte    Cardiomyocyte
# ...                                         ...              ...
# ReichartH46:773447                     Pericyte         Pericyte
# ENCSR814LMX:GCATTGCCAGCAACAG           Pericyte         Pericyte
# ENCSR084XKX:TTGCAATCATCAGTAT           Pericyte         Pericyte
# ENCSR439ZVQ:CCGTTACTCCTCCATA           Pericyte         Pericyte
# TWCM-13-198:GGACATTAGAAGATTC           Pericyte         Pericyte
#
#                              sex_and_age_status
# ENCSR755CIF:ACCACACCATTCCTCG      female:middle
# ENCSR398YBK:TAACCGGTCGTTACAA      female:middle
# ENCSR190TRK:ACATTAGTCATGCTTT      female:middle
# P1582:AGTAACCTCCACCCTA-1-60       female:middle
# H0020_LV:ATACCGAAGAGAGCGG         female:middle
# ...                                         ...
# ReichartH46:773447                   male:young
# ENCSR814LMX:GCATTGCCAGCAACAG         male:young
# ENCSR084XKX:TTGCAATCATCAGTAT         male:young
# ENCSR439ZVQ:CCGTTACTCCTCCATA         male:young
# TWCM-13-198:GGACATTAGAAGATTC         male:young
#
# [15000 rows x 27 columns]

# %%
Counter(adata.obs.age_status)
# Out:
# Counter({'postnatal': 15000})

# %% [markdown]
# ### SCENICplus requires the raw data to be stored in adata.raw

# %%
adata.raw = adata

# %%
adata.obs['updated_cell_type'] = ( adata.obs['final_cell_type'].astype(str) + ":" + 
                                       adata.obs['sex'].astype(str) + ":" +
                                      adata.obs['age_group'].astype(str)  )

# %%
adata.obs['sex_disease_status'] = ( adata.obs['sex'].astype(str) + ":" +
                                      adata.obs['age_group'].astype(str)  )

# %%
Counter(adata.obs.updated_cell_type)
# Out:
# Counter({'Cardiomyocyte:female:middle': 500,
#          'Cardiomyocyte:female:old': 500,
#          'Cardiomyocyte:female:young': 500,
#          'Cardiomyocyte:male:middle': 500,
#          'Cardiomyocyte:male:old': 500,
#          'Cardiomyocyte:male:young': 500,
#          'Endothelial:female:middle': 500,
#          'Endothelial:female:old': 500,
#          'Endothelial:female:young': 500,
#          'Endothelial:male:middle': 500,
#          'Endothelial:male:old': 500,
#          'Endothelial:male:young': 500,
#          'Fibroblast:female:middle': 500,
#          'Fibroblast:female:old': 500,
#          'Fibroblast:female:young': 500,
#          'Fibroblast:male:middle': 500,
#          'Fibroblast:male:old': 500,
#          'Fibroblast:male:young': 500,
#          'Myeloid:female:middle': 500,
#          'Myeloid:female:old': 500,
#          'Myeloid:female:young': 500,
#          'Myeloid:male:middle': 500,
#          'Myeloid:male:old': 500,
#          'Myeloid:male:young': 500,
#          'Pericyte:female:middle': 500,
#          'Pericyte:female:old': 500,
#          'Pericyte:female:young': 500,
#          'Pericyte:male:middle': 500,
#          'Pericyte:male:old': 500,
#          'Pericyte:male:young': 500})

# %%
Counter(adata.obs.sex_disease_status)
# Out:
# Counter({'female:middle': 2500,
#          'female:old': 2500,
#          'female:young': 2500,
#          'male:middle': 2500,
#          'male:old': 2500,
#          'male:young': 2500})

# %%
# %%time
adata.write("03_RNA_adata_for_scenicplus.h5ad")
# Out:
# CPU times: user 234 ms, sys: 642 ms, total: 876 ms
# Wall time: 979 ms

# %%
adata.raw.to_adata()
# Out:
# AnnData object with n_obs × n_vars = 15000 × 16115
#     obs: 'age', 'donor_id', 'sex', 'region', 'cell_type', 'disease', 'consistent_cell_type', 'study', 'technology', 'cell_or_nuclei', 'barcode', 'sample_id', 'age_status', 'tech_plus_study', 'disease_binary', 'decade', 'age_group', '_scvi_batch', '_scvi_labels', 'leiden_scVI', 'scvi_cell_type', 'redo_leiden_0.5', 'UMAP1', 'UMAP2', 'v2_scvi_cell_type', 'final_cell_type', 'sex_and_age_status', 'updated_cell_type', 'sex_disease_status'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
