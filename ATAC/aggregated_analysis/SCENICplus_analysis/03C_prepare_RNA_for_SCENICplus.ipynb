# %% [markdown]
# ### Prepare the RNA adata for SCENIC+:
#
# - see here for example: https://scenicplus.readthedocs.io/en/latest/human_cerebellum_scRNA_pp.html
#
# Since we are interested in the development+disease contrast, we will use the cell type, disease binary, and age status like this: Cardiomyocyte:Y:postnatal and store in 'updated_cell_type'

# %%
import scanpy as sc 
import pandas as pd
import numpy as np
from collections import Counter

# %%
adata = sc.read_h5ad("01_subsampled_RNA.h5ad")
adata.obs_names_make_unique()

# %%
adata.obs
# Out:
#                                           age                        donor_id  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG     18.0                    Penn:Penn_F1
# Fetal-Atria-18wk:TCCGTCCAACAC            18.0                    Penn:Penn_F1
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG  18.0                    Penn:Penn_F1
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA     18.0                    Penn:Penn_F1
# ENCFF849ALE:CGTGTTACAGTACCGT             16.0  ENCODE v4 (Snyder):ENCFF849ALE
# ...                                       ...                             ...
# TWCM-11-74:TTCGGTCGTTCGAATC              65.0          Koenig 2022:TWCM-11-74
# P1516:TTGTGTTCAGTGACCC-1-10              66.0              Chaffin 2022:P1516
# ENCSR762LML:GGTCCTGCATCAGCAC             54.0  ENCODE v4 (Snyder):ENCSR762LML
# ND15755-LV-2nd-run1234:AACTCAGTGGTA      65.0                    Penn:ND15755
# P1549:TCCCATGTCATGAGTC-1-39              49.0              Chaffin 2022:P1549
#
#                                             sex region  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG     female     LV
# Fetal-Atria-18wk:TCCGTCCAACAC            female  Atria
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG  female     LV
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA     female     LV
# ENCFF849ALE:CGTGTTACAGTACCGT             female     WH
# ...                                         ...    ...
# TWCM-11-74:TTCGGTCGTTCGAATC                male     LV
# P1516:TTGTGTTCAGTGACCC-1-10              female     LV
# ENCSR762LML:GGTCCTGCATCAGCAC               male     LV
# ND15755-LV-2nd-run1234:AACTCAGTGGTA        male     LV
# P1549:TCCCATGTCATGAGTC-1-39                male     LV
#
#                                                         cell_type disease  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG                     Lymphoid      ND
# Fetal-Atria-18wk:TCCGTCCAACAC                            Lymphoid      ND
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG                  Lymphoid      ND
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA                     Lymphoid      ND
# ENCFF849ALE:CGTGTTACAGTACCGT                          Endothelial      ND
# ...                                                           ...     ...
# TWCM-11-74:TTCGGTCGTTCGAATC                               Myeloid      ND
# P1516:TTGTGTTCAGTGACCC-1-10                            Macrophage      ND
# ENCSR762LML:GGTCCTGCATCAGCAC                              Myeloid      ND
# ND15755-LV-2nd-run1234:AACTCAGTGGTA                 Cardiomyocyte      ND
# P1549:TCCCATGTCATGAGTC-1-39              Proliferating_macrophage      ND
#
#                                         consistent_cell_type  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG                Lymphoid
# Fetal-Atria-18wk:TCCGTCCAACAC                       Lymphoid
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG             Lymphoid
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA                Lymphoid
# ENCFF849ALE:CGTGTTACAGTACCGT                     Endothelial
# ...                                                      ...
# TWCM-11-74:TTCGGTCGTTCGAATC                          Myeloid
# P1516:TTGTGTTCAGTGACCC-1-10                          Myeloid
# ENCSR762LML:GGTCCTGCATCAGCAC                         Myeloid
# ND15755-LV-2nd-run1234:AACTCAGTGGTA            Cardiomyocyte
# P1549:TCCCATGTCATGAGTC-1-39                          Myeloid
#
#                                                       study   technology  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG                   Penn      Dropseq
# Fetal-Atria-18wk:TCCGTCCAACAC                          Penn      Dropseq
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG                Penn      Dropseq
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA                   Penn      Dropseq
# ENCFF849ALE:CGTGTTACAGTACCGT             ENCODE v4 (Snyder)  Multiome-v1
# ...                                                     ...          ...
# TWCM-11-74:TTCGGTCGTTCGAATC                     Koenig 2022    5prime-v1
# P1516:TTGTGTTCAGTGACCC-1-10                    Chaffin 2022    3prime-v3
# ENCSR762LML:GGTCCTGCATCAGCAC             ENCODE v4 (Snyder)  Multiome-v1
# ND15755-LV-2nd-run1234:AACTCAGTGGTA                    Penn      Dropseq
# P1549:TCCCATGTCATGAGTC-1-39                    Chaffin 2022    3prime-v3
#
#                                         cell_or_nuclei  ... _scvi_labels  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG            Nuclei  ...            0
# Fetal-Atria-18wk:TCCGTCCAACAC                   Nuclei  ...            0
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG         Nuclei  ...            0
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA            Nuclei  ...            0
# ENCFF849ALE:CGTGTTACAGTACCGT                    Nuclei  ...            0
# ...                                                ...  ...          ...
# TWCM-11-74:TTCGGTCGTTCGAATC                     Nuclei  ...            0
# P1516:TTGTGTTCAGTGACCC-1-10                     Nuclei  ...            0
# ENCSR762LML:GGTCCTGCATCAGCAC                    Nuclei  ...            0
# ND15755-LV-2nd-run1234:AACTCAGTGGTA             Nuclei  ...            0
# P1549:TCCCATGTCATGAGTC-1-39                     Nuclei  ...            0
#
#                                         leiden_scVI scvi_cell_type  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG             18    Endothelial
# Fetal-Atria-18wk:TCCGTCCAACAC                    18    Endothelial
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG          18    Endothelial
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA             18    Endothelial
# ENCFF849ALE:CGTGTTACAGTACCGT                     18    Endothelial
# ...                                             ...            ...
# TWCM-11-74:TTCGGTCGTTCGAATC                      14        Myeloid
# P1516:TTGTGTTCAGTGACCC-1-10                      14        Myeloid
# ENCSR762LML:GGTCCTGCATCAGCAC                     14        Myeloid
# ND15755-LV-2nd-run1234:AACTCAGTGGTA              14        Myeloid
# P1549:TCCCATGTCATGAGTC-1-39                      14        Myeloid
#
#                                         redo_leiden_0.5     UMAP1      UMAP2  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG                  8 -3.197946   6.218067
# Fetal-Atria-18wk:TCCGTCCAACAC                         2 -2.106596   6.544215
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG               3 -0.987720   6.037060
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA                  2 -2.163236   6.179525
# ENCFF849ALE:CGTGTTACAGTACCGT                          2 -1.239180   5.651179
# ...                                                 ...       ...        ...
# TWCM-11-74:TTCGGTCGTTCGAATC                           1  1.887421  12.988435
# P1516:TTGTGTTCAGTGACCC-1-10                           8  1.123286  15.893510
# ENCSR762LML:GGTCCTGCATCAGCAC                          9  3.155972  10.162045
# ND15755-LV-2nd-run1234:AACTCAGTGGTA                   9  3.288646  11.371865
# P1549:TCCCATGTCATGAGTC-1-39                          11 -0.044638  17.730947
#
#                                         v2_scvi_cell_type  final_cell_type  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG          Endothelial      Endothelial
# Fetal-Atria-18wk:TCCGTCCAACAC                 Endothelial      Endothelial
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG       Endothelial      Endothelial
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA          Endothelial      Endothelial
# ENCFF849ALE:CGTGTTACAGTACCGT                  Endothelial      Endothelial
# ...                                                   ...              ...
# TWCM-11-74:TTCGGTCGTTCGAATC                       Myeloid          Myeloid
# P1516:TTGTGTTCAGTGACCC-1-10                       Myeloid          Myeloid
# ENCSR762LML:GGTCCTGCATCAGCAC                      Myeloid          Myeloid
# ND15755-LV-2nd-run1234:AACTCAGTGGTA               Myeloid          Myeloid
# P1549:TCCCATGTCATGAGTC-1-39                       Myeloid          Myeloid
#
#                                          disease_and_age_status  \
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG                    N:fetal
# Fetal-Atria-18wk:TCCGTCCAACAC                           N:fetal
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG                 N:fetal
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA                    N:fetal
# ENCFF849ALE:CGTGTTACAGTACCGT                            N:fetal
# ...                                                         ...
# TWCM-11-74:TTCGGTCGTTCGAATC                         N:postnatal
# P1516:TTGTGTTCAGTGACCC-1-10                         N:postnatal
# ENCSR762LML:GGTCCTGCATCAGCAC                        N:postnatal
# ND15755-LV-2nd-run1234:AACTCAGTGGTA                 N:postnatal
# P1549:TCCCATGTCATGAGTC-1-39                         N:postnatal
#
#                                                        group
# Fetal_LV_18wk_e1-run1n2:CCGCGTATTGGG     N:fetal_Endothelial
# Fetal-Atria-18wk:TCCGTCCAACAC            N:fetal_Endothelial
# Fetal-1st-LV-0315-1-run1n2:CGGAGATAACTG  N:fetal_Endothelial
# Fetal_LV_18wk_e1-run1n2:TTGGGCCGGAAA     N:fetal_Endothelial
# ENCFF849ALE:CGTGTTACAGTACCGT             N:fetal_Endothelial
# ...                                                      ...
# TWCM-11-74:TTCGGTCGTTCGAATC              N:postnatal_Myeloid
# P1516:TTGTGTTCAGTGACCC-1-10              N:postnatal_Myeloid
# ENCSR762LML:GGTCCTGCATCAGCAC             N:postnatal_Myeloid
# ND15755-LV-2nd-run1234:AACTCAGTGGTA      N:postnatal_Myeloid
# P1549:TCCCATGTCATGAGTC-1-39              N:postnatal_Myeloid
#
# [13500 rows x 28 columns]

# %%
Counter(adata.obs.age_status)
# Out:
# Counter({'postnatal': 9000, 'fetal': 4500})

# %% [markdown]
# ### SCENICplus requires the raw data to be stored in adata.raw

# %%
adata.raw = adata

# %%
adata.obs['updated_cell_type'] = ( adata.obs['final_cell_type'].astype(str) + ":" + 
                                       adata.obs['disease_binary'].astype(str) + ":" +
                                      adata.obs['age_status'].astype(str)  )

# %%
adata.obs['age_disease_status'] = ( adata.obs['disease_binary'].astype(str) + ":" +
                                      adata.obs['age_status'].astype(str)  )

# %%
Counter(adata.obs.updated_cell_type)
# Out:
# Counter({'Endothelial:N:fetal': 750,
#          'Endothelial:Y:postnatal': 750,
#          'Endothelial:N:postnatal': 750,
#          'Lymphoid:N:fetal': 750,
#          'Lymphoid:Y:postnatal': 750,
#          'Lymphoid:N:postnatal': 750,
#          'Fibroblast:N:fetal': 750,
#          'Fibroblast:Y:postnatal': 750,
#          'Fibroblast:N:postnatal': 750,
#          'Cardiomyocyte:N:fetal': 750,
#          'Cardiomyocyte:Y:postnatal': 750,
#          'Cardiomyocyte:N:postnatal': 750,
#          'Pericyte:N:fetal': 750,
#          'Pericyte:Y:postnatal': 750,
#          'Pericyte:N:postnatal': 750,
#          'Myeloid:N:fetal': 750,
#          'Myeloid:Y:postnatal': 750,
#          'Myeloid:N:postnatal': 750})

# %%
Counter(adata.obs.age_disease_status)
# Out:
# Counter({'N:fetal': 4500, 'Y:postnatal': 4500, 'N:postnatal': 4500})

# %%
# %%time
adata.write("03_RNA_adata_for_scenicplus.h5ad")
# Out:
# CPU times: user 288 ms, sys: 522 ms, total: 811 ms
# Wall time: 809 ms
