# %% [markdown]
# ### Reformat original metadata
#
# - `00_original_metadata.csv` contains metadata information from individually examining each study. We will reformat this to make sure that its metadata is concordant with the snRNA-seq aggregated analysis, especially with Multiome data

# %%
import pandas as pd
import numpy as np
import scanpy as sc
from collections import Counter
import os

# %%
metadata_df = pd.read_csv("00_original_metadata.csv", index_col = 0)
metadata_df = metadata_df[["sample_id", "donor_id", "study", "age_status", "age", 
                           "sex", "region", "disease_binary", "technology", "full_path"]].reset_index(drop=True)
metadata_df.head()
# Out:
#         sample_id donor_id  study age_status   age     sex region  \
# 0  10X_ATAC_CK166       P1  Kuppe  Postnatal  44.0    male     LV
# 1  10X_ATAC_CK337       P7  Kuppe  Postnatal  55.0  female     LV
# 2  10X_ATAC_CK338       P8  Kuppe  Postnatal  44.0    male     LV
# 3  10X_ATAC_CK353      P17  Kuppe  Postnatal  61.0    male     LV
# 4  10X_ATAC_CK381      P17  Kuppe  Postnatal  61.0    male     LV
#
#   disease_binary technology              full_path
# 0   non-diseased   10X_ATAC  10X_ATAC_CK166.tsv.gz
# 1   non-diseased   10X_ATAC  10X_ATAC_CK337.tsv.gz
# 2   non-diseased   10X_ATAC  10X_ATAC_CK338.tsv.gz
# 3   non-diseased   10X_ATAC  10X_ATAC_CK353.tsv.gz
# 4   non-diseased   10X_ATAC  10X_ATAC_CK381.tsv.gz

# %%
metadata_df['fragment_file'] = metadata_df['full_path'].str.split("/").str[-1]
metadata_df = metadata_df.drop(columns = "full_path")
metadata_df['full_path'] = metadata_df['fragment_file']

# %%
Counter(metadata_df.study)
# Out:
# Counter({'ENCODE': 72, 'Kuppe': 28, 'Penn': 22, 'Kanemaru': 7, 'Ameen': 3})

# %% [markdown]
# #### Add the directory to fragment file name to get the full path

# %%
study_to_base_path = {
    "Kuppe": "/mnt/data1/william/human_heart_project/Final_manuscript_analysis/ATAC/external_datasets/Kuppe/",
    "ENCODE": "/mnt/data1/william/human_heart_project/Final_manuscript_analysis/ATAC/external_datasets/ENCODE/",
    "Penn": "/mnt/data1/william/human_heart_project/Final_manuscript_analysis/ATAC/internal_datasets/fragment_files/",
    "Kanemaru": "/mnt/data1/william/human_heart_project/Final_manuscript_analysis/ATAC/external_datasets/Kanemaru/",
    "Ameen": "/mnt/data1/william/human_heart_project/Final_manuscript_analysis/ATAC/external_datasets/Ameen/",
}

# %%
for study, base_path in study_to_base_path.items():
    mask = metadata_df['study'] == study  # Create a mask for the current study
    metadata_df.loc[mask, 'full_path'] = base_path + metadata_df.loc[mask, 'full_path']

# %%
# check that file exists
metadata_df['file_exists'] = metadata_df['full_path'].apply(os.path.exists)

print(metadata_df[metadata_df['file_exists'] != True])
# Out:
# Empty DataFrame
# Columns: [sample_id, donor_id, study, age_status, age, sex, region, disease_binary, technology, fragment_file, full_path, file_exists]
# Index: []

# %% [markdown]
# #### Check the metadata and make it consistent with snRNA-seq

# %%
Counter(metadata_df.region)
# Out:
# Counter({'LV': 89,
#          'WH': 14,
#          'FZ': 5,
#          'GT/IZ': 5,
#          'RZ': 4,
#          'RZ/BZ': 3,
#          'OFT': 3,
#          'LRV': 3,
#          'FZ/GT': 2,
#          'IZ': 2,
#          'RZ/FZ': 1,
#          'IZ/BZ': 1})

# %%
Counter(metadata_df.sample_id)
# Out:
# Counter({'10X_ATAC_CK166': 1,
#          '10X_ATAC_CK337': 1,
#          '10X_ATAC_CK338': 1,
#          '10X_ATAC_CK353': 1,
#          '10X_ATAC_CK381': 1,
#          'K1485-run-1': 1,
#          'K1485-run-2': 1,
#          'K1488-run-1': 1,
#          'K1488-run-2': 1,
#          'K1584-run-1': 1,
#          'K1584-run-2': 1,
#          'K1647-run-1': 1,
#          'K1647-run-2': 1,
#          'K1727-LV-1': 1,
#          'K1727-LV-2': 1,
#          'NDRI15755_10k': 1,
#          'NDRI15755_5k': 1,
#          'HCAHeart9508627_HCAHeart9508819': 1,
#          'HCAHeart9508629_HCAHeart9508821': 1,
#          'HCAHeart9845431_HCAHeart9917173': 1,
#          'HCAHeartST10773165_HCAHeartST10781062': 1,
#          'HCAHeartST10773166_HCAHeartST10781063': 1,
#          'HCAHeartST11064574_HCAHeartST11023239': 1,
#          'HCAHeartST11064575_HCAHeartST11023240': 1,
#          'ENCSR506ROZ': 1,
#          'ENCSR088ZOL': 1,
#          'ENCSR318ERF': 1,
#          'ENCSR233KYH': 1,
#          'ENCSR785BSP': 1,
#          'ENCSR912XZH': 1,
#          'ENCSR594WKI': 1,
#          'ENCSR305KUV': 1,
#          'ENCSR627IOJ': 1,
#          'ENCSR161IHV': 1,
#          'ENCSR642ZIC': 1,
#          'ENCSR003DSI': 1,
#          'ENCSR270CUT': 1,
#          'ENCSR701JAT': 1,
#          'ENCSR686FZG': 1,
#          'ENCSR079TCC': 1,
#          'ENCSR617IKC': 1,
#          'ENCSR718YPN': 1,
#          'ENCSR951AID': 1,
#          'ENCSR101LQQ': 1,
#          'ENCSR084DVM': 1,
#          'ENCSR131DKN': 1,
#          'ENCSR435CGY': 1,
#          'ENCSR987PQH': 1,
#          'ENCSR173UUN': 1,
#          'ENCSR051ECW': 1,
#          'ENCSR511VYN': 1,
#          'ENCSR657WLS': 1,
#          'ENCSR878VJS': 1,
#          'ENCSR668XPI': 1,
#          'ENCSR918VTH': 1,
#          'ENCSR280RVT': 1,
#          'ENCSR769WLL': 1,
#          'ENCSR320QOP': 1,
#          'ENCSR702ELN': 1,
#          'ENCSR406CJH': 1,
#          'ENCSR450VTB': 1,
#          'ENCSR750YRO': 1,
#          'ENCSR531ZKI': 1,
#          'ENCSR185NXG': 1,
#          'ENCSR409QLZ': 1,
#          'ENCSR175JHG': 1,
#          'ENCSR033ENA': 1,
#          'ENCSR321AHR': 1,
#          'ENCSR546WZB': 1,
#          'ENCSR862IWS': 1,
#          'ENCSR960IDI': 1,
#          'ENCSR020FAW': 1,
#          'ENCSR412VTJ': 1,
#          'ENCSR495SMB': 1,
#          'ENCSR061BEN': 1,
#          'ENCSR494FFG': 1,
#          'ENCSR273DAC': 1,
#          'ENCSR722PYH': 1,
#          'ENCSR958FFE': 1,
#          'ENCSR556UHL': 1,
#          'ENCSR895LPX': 1,
#          'ENCSR288RQI': 1,
#          'ENCSR803QTN': 1,
#          'ENCSR277LDY': 1,
#          'ENCSR080TZR': 1,
#          'ENCSR886PUY': 1,
#          'ENCSR913OAS': 1,
#          '10X_ATAC_CK385': 1,
#          '10X_ATAC_CK340': 1,
#          '10X_ATAC_CK388': 1,
#          '10X_ATAC_CK349': 1,
#          '10X_ATAC_CK167': 1,
#          '10X_ATAC_CK389': 1,
#          '10X_ATAC_CK168': 1,
#          '10X_ATAC_CK341': 1,
#          '10X_ATAC_CK171': 1,
#          '10X_ATAC_CK351': 1,
#          '10X_ATAC_CK174': 1,
#          '10X_ATAC_CK382': 1,
#          '10X_ATAC_CK383': 1,
#          '10X_ATAC_CK343': 1,
#          '10X_ATAC_CK336': 1,
#          '10X_ATAC_CK173': 1,
#          '10X_ATAC_CK380': 1,
#          '10X_ATAC_CK170': 1,
#          '10X_ATAC_CK346': 1,
#          '10X_ATAC_CK352': 1,
#          '10X_ATAC_CK354': 1,
#          '10X_ATAC_CK350': 1,
#          '10X_ATAC_CK387': 1,
#          'Fetal-OFT-2': 1,
#          'Fetal-LRV-1': 1,
#          'Fetal-wholeHeart-10wk': 1,
#          'Fetal-LV-2': 1,
#          'Fetal-LV-1': 1,
#          'Fetal-LRV-2': 1,
#          'Fetal-LRV-14wk': 1,
#          'Fetal-OFT-14wk': 1,
#          'Fetal-heart-8wk': 1,
#          'Fetal-OFT-1': 1,
#          'GSM5495103_F8_v2': 1,
#          'GSM5495102_F6_v2': 1,
#          'GSM5495104_F19_v2': 1,
#          'ENCFF958UTA': 1,
#          'ENCFF904ARJ': 1,
#          'ENCFF658TEH': 1,
#          'ENCFF109FJX': 1,
#          'ENCFF575DGZ': 1,
#          'ENCFF851VTB': 1,
#          'ENCFF401MVS': 1,
#          'ENCFF946HNM': 1,
#          'ENCFF908JHS': 1})

# %%
Counter(metadata_df.donor_id)
# Out:
# Counter({'P9': 5,
#          'AH1': 4,
#          'Penn_F2': 4,
#          'P17': 2,
#          'K1485': 2,
#          'K1488': 2,
#          'K1584': 2,
#          'K1647': 2,
#          'K1727': 2,
#          'ND15755': 2,
#          'P20': 2,
#          'P3': 2,
#          'P2': 2,
#          'P14': 2,
#          'P15': 2,
#          'Penn_F1': 2,
#          'Penn_F5': 2,
#          'P1': 1,
#          'P7': 1,
#          'P8': 1,
#          'D3': 1,
#          'D7': 1,
#          'D8': 1,
#          'ENCSR506ROZ': 1,
#          'ENCSR088ZOL': 1,
#          'ENCSR318ERF': 1,
#          'ENCSR233KYH': 1,
#          'ENCSR785BSP': 1,
#          'ENCSR912XZH': 1,
#          'ENCSR594WKI': 1,
#          'ENCSR305KUV': 1,
#          'ENCSR627IOJ': 1,
#          'ENCSR161IHV': 1,
#          'ENCSR642ZIC': 1,
#          'ENCSR003DSI': 1,
#          'ENCSR270CUT': 1,
#          'ENCSR701JAT': 1,
#          'ENCSR686FZG': 1,
#          'ENCSR079TCC': 1,
#          'ENCSR617IKC': 1,
#          'ENCSR718YPN': 1,
#          'ENCSR951AID': 1,
#          'ENCSR101LQQ': 1,
#          'ENCSR084DVM': 1,
#          'ENCSR131DKN': 1,
#          'ENCSR435CGY': 1,
#          'ENCSR987PQH': 1,
#          'ENCSR173UUN': 1,
#          'ENCSR051ECW': 1,
#          'ENCSR511VYN': 1,
#          'ENCSR657WLS': 1,
#          'ENCSR878VJS': 1,
#          'ENCSR668XPI': 1,
#          'ENCSR918VTH': 1,
#          'ENCSR280RVT': 1,
#          'ENCSR769WLL': 1,
#          'ENCSR320QOP': 1,
#          'ENCSR702ELN': 1,
#          'ENCSR406CJH': 1,
#          'ENCSR450VTB': 1,
#          'ENCSR750YRO': 1,
#          'ENCSR531ZKI': 1,
#          'ENCSR185NXG': 1,
#          'ENCSR409QLZ': 1,
#          'ENCSR175JHG': 1,
#          'ENCSR033ENA': 1,
#          'ENCSR321AHR': 1,
#          'ENCSR546WZB': 1,
#          'ENCSR862IWS': 1,
#          'ENCSR960IDI': 1,
#          'ENCSR020FAW': 1,
#          'ENCSR412VTJ': 1,
#          'ENCSR495SMB': 1,
#          'ENCSR061BEN': 1,
#          'ENCSR494FFG': 1,
#          'ENCSR273DAC': 1,
#          'ENCSR722PYH': 1,
#          'ENCSR958FFE': 1,
#          'ENCSR556UHL': 1,
#          'ENCSR895LPX': 1,
#          'ENCSR288RQI': 1,
#          'ENCSR803QTN': 1,
#          'ENCSR277LDY': 1,
#          'ENCSR080TZR': 1,
#          'ENCSR886PUY': 1,
#          'ENCSR913OAS': 1,
#          'P12': 1,
#          'P18': 1,
#          'P5': 1,
#          'P19': 1,
#          'P10': 1,
#          'P6': 1,
#          'P11': 1,
#          'P4': 1,
#          'Penn_F4': 1,
#          'Penn_F3': 1,
#          'GSM5495103_F8_v2': 1,
#          'GSM5495102_F6_v2': 1,
#          'GSM5495104_F19_v2': 1,
#          'ENCFF958UTA': 1,
#          'ENCFF904ARJ': 1,
#          'ENCFF658TEH': 1,
#          'ENCFF109FJX': 1,
#          'ENCFF575DGZ': 1,
#          'ENCFF851VTB': 1,
#          'ENCFF401MVS': 1,
#          'ENCFF946HNM': 1,
#          'ENCFF908JHS': 1})

# %%
Counter(metadata_df.age_status)
# Out:
# Counter({'Postnatal': 110, 'Fetal': 22})

# %%
Counter(metadata_df.disease_binary)
# Out:
# Counter({'non-diseased': 109, 'diseased': 23})

# %%
metadata_df.loc[metadata_df.disease_binary == "non-diseased", 'disease_binary'] = "N"
metadata_df.loc[metadata_df.disease_binary == "diseased", 'disease_binary'] = "Y"
Counter(metadata_df.disease_binary)
# Out:
# Counter({'N': 109, 'Y': 23})

# %%
Counter(metadata_df.sex)
# Out:
# Counter({'male': 90, 'female': 42})

# %% [markdown]
# ### Load in the RNA adata

# %%
# %%time
RNA_adata = sc.read_h5ad("../../RNA/aggregated_analysis/03_combined_all_snRNA.h5ad")
RNA_adata
# Out:
# CPU times: user 14.9 s, sys: 1min 38s, total: 1min 53s
# Wall time: 1min 53s
# AnnData object with n_obs × n_vars = 2841357 × 13640
#     obs: 'age', 'donor_id', 'sex', 'region', 'cell_type', 'disease', 'consistent_cell_type', 'study', 'technology', 'cell_or_nuclei', 'barcode', 'sample_id', 'age_status', 'tech_plus_study', 'disease_binary', 'age_group'
#     layers: 'count', 'counts'

# %%
RNA_donors = set(RNA_adata.obs.donor_id)
RNA_donors
# Out:
# {'Chaffin 2022:P1290',
#  'Chaffin 2022:P1300',
#  'Chaffin 2022:P1304',
#  'Chaffin 2022:P1358',
#  'Chaffin 2022:P1371',
#  'Chaffin 2022:P1422',
#  'Chaffin 2022:P1425',
#  'Chaffin 2022:P1430',
#  'Chaffin 2022:P1437',
#  'Chaffin 2022:P1447',
#  'Chaffin 2022:P1462',
#  'Chaffin 2022:P1472',
#  'Chaffin 2022:P1479',
#  'Chaffin 2022:P1504',
#  'Chaffin 2022:P1508',
#  'Chaffin 2022:P1510',
#  'Chaffin 2022:P1515',
#  'Chaffin 2022:P1516',
#  'Chaffin 2022:P1539',
#  'Chaffin 2022:P1540',
#  'Chaffin 2022:P1547',
#  'Chaffin 2022:P1549',
#  'Chaffin 2022:P1558',
#  'Chaffin 2022:P1561',
#  'Chaffin 2022:P1582',
#  'Chaffin 2022:P1600',
#  'Chaffin 2022:P1602',
#  'Chaffin 2022:P1603',
#  'Chaffin 2022:P1606',
#  'Chaffin 2022:P1610',
#  'Chaffin 2022:P1617',
#  'Chaffin 2022:P1622',
#  'Chaffin 2022:P1630',
#  'Chaffin 2022:P1631',
#  'Chaffin 2022:P1678',
#  'Chaffin 2022:P1685',
#  'Chaffin 2022:P1702',
#  'Chaffin 2022:P1707',
#  'Chaffin 2022:P1718',
#  'Chaffin 2022:P1722',
#  'Chaffin 2022:P1726',
#  'Chaffin 2022:P1735',
#  'ENCODE v4 (Snyder):ENCFF248EWR',
#  'ENCODE v4 (Snyder):ENCFF684YRB',
#  'ENCODE v4 (Snyder):ENCFF727JRO',
#  'ENCODE v4 (Snyder):ENCFF775ANN',
#  'ENCODE v4 (Snyder):ENCFF776DQR',
#  'ENCODE v4 (Snyder):ENCFF802AQC',
#  'ENCODE v4 (Snyder):ENCFF805YRY',
#  'ENCODE v4 (Snyder):ENCFF849ALE',
#  'ENCODE v4 (Snyder):ENCSR002SMQ',
#  'ENCODE v4 (Snyder):ENCSR008CVR',
#  'ENCODE v4 (Snyder):ENCSR012APQ',
#  'ENCODE v4 (Snyder):ENCSR056QLB',
#  'ENCODE v4 (Snyder):ENCSR067BOK',
#  'ENCODE v4 (Snyder):ENCSR076ZLE',
#  'ENCODE v4 (Snyder):ENCSR084XKX',
#  'ENCODE v4 (Snyder):ENCSR085XEW',
#  'ENCODE v4 (Snyder):ENCSR093GXF',
#  'ENCODE v4 (Snyder):ENCSR138JCM',
#  'ENCODE v4 (Snyder):ENCSR157FDD',
#  'ENCODE v4 (Snyder):ENCSR175TRJ',
#  'ENCODE v4 (Snyder):ENCSR176WWW',
#  'ENCODE v4 (Snyder):ENCSR190TRK',
#  'ENCODE v4 (Snyder):ENCSR203YOV',
#  'ENCODE v4 (Snyder):ENCSR204RHR',
#  'ENCODE v4 (Snyder):ENCSR231FNL',
#  'ENCODE v4 (Snyder):ENCSR237HWJ',
#  'ENCODE v4 (Snyder):ENCSR259VOY',
#  'ENCODE v4 (Snyder):ENCSR273JWD',
#  'ENCODE v4 (Snyder):ENCSR328GTN',
#  'ENCODE v4 (Snyder):ENCSR345CVL',
#  'ENCODE v4 (Snyder):ENCSR349AHE',
#  'ENCODE v4 (Snyder):ENCSR352DXB',
#  'ENCODE v4 (Snyder):ENCSR398YBK',
#  'ENCODE v4 (Snyder):ENCSR405YKM',
#  'ENCODE v4 (Snyder):ENCSR439ZVQ',
#  'ENCODE v4 (Snyder):ENCSR455MGH',
#  'ENCODE v4 (Snyder):ENCSR481QQR',
#  'ENCODE v4 (Snyder):ENCSR485GOL',
#  'ENCODE v4 (Snyder):ENCSR488UUT',
#  'ENCODE v4 (Snyder):ENCSR489URW',
#  'ENCODE v4 (Snyder):ENCSR540DHJ',
#  'ENCODE v4 (Snyder):ENCSR630LZS',
#  'ENCODE v4 (Snyder):ENCSR654MFX',
#  'ENCODE v4 (Snyder):ENCSR681GPY',
#  'ENCODE v4 (Snyder):ENCSR727OYO',
#  'ENCODE v4 (Snyder):ENCSR751BHQ',
#  'ENCODE v4 (Snyder):ENCSR753YOZ',
#  'ENCODE v4 (Snyder):ENCSR755CIF',
#  'ENCODE v4 (Snyder):ENCSR762LML',
#  'ENCODE v4 (Snyder):ENCSR763BII',
#  'ENCODE v4 (Snyder):ENCSR777RUZ',
#  'ENCODE v4 (Snyder):ENCSR788SNY',
#  'ENCODE v4 (Snyder):ENCSR801DHT',
#  'ENCODE v4 (Snyder):ENCSR814LMX',
#  'ENCODE v4 (Snyder):ENCSR851JBE',
#  'ENCODE v4 (Snyder):ENCSR899GYX',
#  'ENCODE v4 (Snyder):ENCSR906MRL',
#  'ENCODE v4 (Snyder):ENCSR919ENI',
#  'ENCODE v4 (Snyder):ENCSR962JKS',
#  'ENCODE v4 (Snyder):ENCSR980OCK',
#  'ENCODE v4 (Snyder):ENCSR991LHO',
#  'ENCODE v4 (Snyder):ENCSR994VEG',
#  'Hill 2022:TWCM-13-198',
#  'Hill 2022:UK1',
#  'Hill 2022:UK2',
#  'Kanemaru 2023:AH1-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D3-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D7-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D8-Nuclei_Multiome-v1',
#  'Koenig 2022:H_ZC-11-292',
#  'Koenig 2022:H_ZC-LVAD',
#  'Koenig 2022:TWCM-10-5',
#  'Koenig 2022:TWCM-10-68',
#  'Koenig 2022:TWCM-11-103',
#  'Koenig 2022:TWCM-11-104',
#  'Koenig 2022:TWCM-11-192',
#  'Koenig 2022:TWCM-11-256',
#  'Koenig 2022:TWCM-11-264',
#  'Koenig 2022:TWCM-11-41',
#  'Koenig 2022:TWCM-11-42',
#  'Koenig 2022:TWCM-11-74',
#  'Koenig 2022:TWCM-11-78',
#  'Koenig 2022:TWCM-11-82',
#  'Koenig 2022:TWCM-11-93',
#  'Koenig 2022:TWCM-13-1',
#  'Koenig 2022:TWCM-13-101',
#  'Koenig 2022:TWCM-13-102',
#  'Koenig 2022:TWCM-13-104',
#  'Koenig 2022:TWCM-13-132',
#  'Koenig 2022:TWCM-13-152',
#  'Koenig 2022:TWCM-13-168',
#  'Koenig 2022:TWCM-13-17',
#  'Koenig 2022:TWCM-13-181',
#  'Koenig 2022:TWCM-13-192',
#  'Koenig 2022:TWCM-13-198',
#  'Koenig 2022:TWCM-13-208',
#  'Koenig 2022:TWCM-13-235',
#  'Koenig 2022:TWCM-13-285',
#  'Koenig 2022:TWCM-13-36',
#  'Koenig 2022:TWCM-13-47',
#  'Koenig 2022:TWCM-13-80',
#  'Koenig 2022:TWCM-13-84',
#  'Koenig 2022:TWCM-13-96',
#  'Koenig 2022:TWCM-14-173',
#  'Koenig 2022:TWCM-LVAD2',
#  'Koenig 2022:TWCM-LVAD3',
#  'Kuppe 2022:P1',
#  'Kuppe 2022:P10',
#  'Kuppe 2022:P11',
#  'Kuppe 2022:P12',
#  'Kuppe 2022:P13',
#  'Kuppe 2022:P14',
#  'Kuppe 2022:P15',
#  'Kuppe 2022:P16',
#  'Kuppe 2022:P17',
#  'Kuppe 2022:P18',
#  'Kuppe 2022:P19',
#  'Kuppe 2022:P2',
#  'Kuppe 2022:P20',
#  'Kuppe 2022:P3',
#  'Kuppe 2022:P4',
#  'Kuppe 2022:P6',
#  'Kuppe 2022:P7',
#  'Kuppe 2022:P8',
#  'Kuppe 2022:P9',
#  'Litvinukova 2020:D1-Nuclei_3prime-v2',
#  'Litvinukova 2020:D11-Nuclei_3prime-v3',
#  'Litvinukova 2020:D2-Nuclei_3prime-v2',
#  'Litvinukova 2020:D3-Nuclei_3prime-v2',
#  'Litvinukova 2020:D4-Nuclei_3prime-v2',
#  'Litvinukova 2020:D5-Nuclei_3prime-v2',
#  'Litvinukova 2020:D6-Nuclei_3prime-v2',
#  'Litvinukova 2020:D7-Nuclei_3prime-v2',
#  'Litvinukova 2020:H2-Nuclei_3prime-v3',
#  'Litvinukova 2020:H3-Nuclei_3prime-v3',
#  'Litvinukova 2020:H4-Nuclei_3prime-v3',
#  'Litvinukova 2020:H5-Nuclei_3prime-v3',
#  'Litvinukova 2020:H6-Nuclei_3prime-v3',
#  'Litvinukova 2020:H7-Nuclei_3prime-v3',
#  'Penn:K1430',
#  'Penn:K1485',
#  'Penn:K1488',
#  'Penn:K1545',
#  'Penn:K1549',
#  'Penn:K1561',
#  'Penn:K1570',
#  'Penn:K1584',
#  'Penn:K1617',
#  'Penn:K1622',
#  'Penn:K1647',
#  'Penn:K1702',
#  'Penn:K1718',
#  'Penn:K1727',
#  'Penn:K1739',
#  'Penn:ND15755',
#  'Penn:ND15840',
#  'Penn:Penn_F1',
#  'Penn:Penn_F2',
#  'Reichart 2022:ReichartDL2',
#  'Reichart 2022:ReichartDL3',
#  'Reichart 2022:ReichartDO1',
#  'Reichart 2022:ReichartDP1',
#  'Reichart 2022:ReichartDP2',
#  'Reichart 2022:ReichartDS3',
#  'Reichart 2022:ReichartDT4',
#  'Reichart 2022:ReichartH01',
#  'Reichart 2022:ReichartH02',
#  'Reichart 2022:ReichartH03',
#  'Reichart 2022:ReichartH04',
#  'Reichart 2022:ReichartH05',
#  'Reichart 2022:ReichartH06',
#  'Reichart 2022:ReichartH07',
#  'Reichart 2022:ReichartH08',
#  'Reichart 2022:ReichartH09',
#  'Reichart 2022:ReichartH10',
#  'Reichart 2022:ReichartH11',
#  'Reichart 2022:ReichartH12',
#  'Reichart 2022:ReichartH13',
#  'Reichart 2022:ReichartH14',
#  'Reichart 2022:ReichartH15',
#  'Reichart 2022:ReichartH16',
#  'Reichart 2022:ReichartH17',
#  'Reichart 2022:ReichartH18',
#  'Reichart 2022:ReichartH19',
#  'Reichart 2022:ReichartH20',
#  'Reichart 2022:ReichartH21',
#  'Reichart 2022:ReichartH22',
#  'Reichart 2022:ReichartH24',
#  'Reichart 2022:ReichartH25',
#  'Reichart 2022:ReichartH26',
#  'Reichart 2022:ReichartH27',
#  'Reichart 2022:ReichartH28',
#  'Reichart 2022:ReichartH29',
#  'Reichart 2022:ReichartH31',
#  'Reichart 2022:ReichartH32',
#  'Reichart 2022:ReichartH33',
#  'Reichart 2022:ReichartH34',
#  'Reichart 2022:ReichartH35',
#  'Reichart 2022:ReichartH36',
#  'Reichart 2022:ReichartH37',
#  'Reichart 2022:ReichartH39',
#  'Reichart 2022:ReichartH40',
#  'Reichart 2022:ReichartH41',
#  'Reichart 2022:ReichartH42',
#  'Reichart 2022:ReichartH44',
#  'Reichart 2022:ReichartH46',
#  'Reichart 2022:ReichartH49',
#  'Reichart 2022:ReichartH51',
#  'Reichart 2022:ReichartH53',
#  'Reichart 2022:ReichartH55',
#  'Reichart 2022:ReichartH56',
#  'Reichart 2022:ReichartH57',
#  'Reichart 2022:ReichartH58',
#  'Reichart 2022:ReichartH59',
#  'Reichart 2022:ReichartH67',
#  'Reichart 2022:ReichartH73',
#  'Reichart 2022:ReichartH78',
#  'Reichart 2022:ReichartH79',
#  'Reichart 2022:ReichartH80',
#  'Reichart 2022:ReichartH81',
#  'Reichart 2022:ReichartH84',
#  'Reichart 2022:ReichartIC_H01',
#  'Reichart 2022:ReichartIC_H02',
#  'Reichart 2022:ReichartIC_H03',
#  'Reichart 2022:ReichartIC_H04',
#  'Sim 2021:GSM4742854_Adult1_processed',
#  'Sim 2021:GSM4742855_Adult2_processed',
#  'Sim 2021:GSM4742856_Adult3_processed',
#  'Sim 2021:GSM4742857_Fetal1_processed',
#  'Sim 2021:GSM4742858_Fetal2_processed',
#  'Sim 2021:GSM4742859_Fetal3_processed',
#  'Sim 2021:GSM4742860_Young1_processed',
#  'Sim 2021:GSM4742861_Young2_processed',
#  'Sim 2021:GSM4742862_Young3_processed',
#  'Simonson 2023:P1364',
#  'Simonson 2023:P1452',
#  'Simonson 2023:P1579',
#  'Simonson 2023:P1650',
#  'Simonson 2023:P1690',
#  'Simonson 2023:P1693',
#  'Simonson 2023:P1703',
#  'Simonson 2023:P1716',
#  'Simonson 2023:P1733',
#  'Simonson 2023:P1739',
#  'Simonson 2023:P1763',
#  'Simonson 2023:P1773',
#  'Simonson 2023:P1785',
#  'Simonson 2023:P1800',
#  'Simonson 2023:P1801'}

# %% [markdown]
# ### The ATAC donor_id and studies need to be consistent.
#
# #### For study, we will add the year of the study

# %%
Counter(metadata_df['study'])
# Out:
# Counter({'ENCODE': 72, 'Kuppe': 28, 'Penn': 22, 'Kanemaru': 7, 'Ameen': 3})

# %%
metadata_df['revised_study'] = metadata_df['study'].map(
    {
        "Kuppe": "Kuppe 2022",
        "Kanemaru": "Kanemaru 2023",
        "ENCODE": "ENCODE v4 (Snyder)",
        "Penn": "Penn",
        "Ameen": "Ameen 2022"
    }
)

metadata_df['study'] = metadata_df['revised_study']
metadata_df = metadata_df.drop(columns = ['revised_study'])

# %%
Counter(metadata_df['study'])
# Out:
# Counter({'ENCODE v4 (Snyder)': 72,
#          'Kuppe 2022': 28,
#          'Penn': 22,
#          'Kanemaru 2023': 7,
#          'Ameen 2022': 3})

# %% [markdown]
# #### Now, add the study to the donor_id in the ATAC metadata

# %%
metadata_df['donor_id'] = metadata_df['study'] + ":" + metadata_df['donor_id']

# %%
# examine intersection between RNA and ATAC 
set(metadata_df['donor_id']) & RNA_donors
# Out:
# {'Kuppe 2022:P1',
#  'Kuppe 2022:P10',
#  'Kuppe 2022:P11',
#  'Kuppe 2022:P12',
#  'Kuppe 2022:P14',
#  'Kuppe 2022:P15',
#  'Kuppe 2022:P17',
#  'Kuppe 2022:P18',
#  'Kuppe 2022:P19',
#  'Kuppe 2022:P2',
#  'Kuppe 2022:P20',
#  'Kuppe 2022:P3',
#  'Kuppe 2022:P4',
#  'Kuppe 2022:P6',
#  'Kuppe 2022:P7',
#  'Kuppe 2022:P8',
#  'Kuppe 2022:P9',
#  'Penn:K1485',
#  'Penn:K1488',
#  'Penn:K1584',
#  'Penn:K1647',
#  'Penn:K1727',
#  'Penn:ND15755',
#  'Penn:Penn_F1',
#  'Penn:Penn_F2'}

# %%
metadata_df[metadata_df['study']  == "Kanemaru 2023"]
# Out:
#                                 sample_id           donor_id          study  \
# 17        HCAHeart9508627_HCAHeart9508819   Kanemaru 2023:D3  Kanemaru 2023
# 18        HCAHeart9508629_HCAHeart9508821   Kanemaru 2023:D7  Kanemaru 2023
# 19        HCAHeart9845431_HCAHeart9917173   Kanemaru 2023:D8  Kanemaru 2023
# 20  HCAHeartST10773165_HCAHeartST10781062  Kanemaru 2023:AH1  Kanemaru 2023
# 21  HCAHeartST10773166_HCAHeartST10781063  Kanemaru 2023:AH1  Kanemaru 2023
# 22  HCAHeartST11064574_HCAHeartST11023239  Kanemaru 2023:AH1  Kanemaru 2023
# 23  HCAHeartST11064575_HCAHeartST11023240  Kanemaru 2023:AH1  Kanemaru 2023
#
#    age_status   age     sex region disease_binary    technology  \
# 17  Postnatal  57.5    male     LV              N  10X_Multiome
# 18  Postnatal  62.5    male     LV              N  10X_Multiome
# 19  Postnatal  47.5    male     LV              N  10X_Multiome
# 20  Postnatal  47.5  female     LV              N  10X_Multiome
# 21  Postnatal  47.5  female     LV              N  10X_Multiome
# 22  Postnatal  47.5  female     LV              N  10X_Multiome
# 23  Postnatal  47.5  female     LV              N  10X_Multiome
#
#                                         fragment_file  \
# 17   HCAHeart9508627_HCAHeart9508819_fragments.tsv.gz
# 18   HCAHeart9508629_HCAHeart9508821_fragments.tsv.gz
# 19   HCAHeart9845431_HCAHeart9917173_fragments.tsv.gz
# 20  HCAHeartST10773165_HCAHeartST10781062_fragment...
# 21  HCAHeartST10773166_HCAHeartST10781063_fragment...
# 22  HCAHeartST11064574_HCAHeartST11023239_fragment...
# 23  HCAHeartST11064575_HCAHeartST11023240_fragment...
#
#                                             full_path  file_exists
# 17  /mnt/data1/william/human_heart_project/Final_m...         True
# 18  /mnt/data1/william/human_heart_project/Final_m...         True
# 19  /mnt/data1/william/human_heart_project/Final_m...         True
# 20  /mnt/data1/william/human_heart_project/Final_m...         True
# 21  /mnt/data1/william/human_heart_project/Final_m...         True
# 22  /mnt/data1/william/human_heart_project/Final_m...         True
# 23  /mnt/data1/william/human_heart_project/Final_m...         True

# %% [markdown]
# #### The Kanemaru donor_ids need to be renamed to be consistent with the names in the snRNA-seq dataset
# RNA-seq:
# - 'Kanemaru 2023:AH1-Nuclei_Multiome-v1'
# - 'Kanemaru 2023:D3-Nuclei_Multiome-v1'
# - 'Kanemaru 2023:D7-Nuclei_Multiome-v1'
# - 'Kanemaru 2023:D8-Nuclei_Multiome-v1',
#
# currently ATAC-seq is just: Kanemaru 2023:D3, Kanemaru 2023:D7, Kanemaru 2023:D8, Kanemaru 2023:AH1

# %%
metadata_df.loc[metadata_df['donor_id'] == "Kanemaru 2023:D3", 'donor_id'] = "Kanemaru 2023:D3-Nuclei_Multiome-v1"
metadata_df.loc[metadata_df['donor_id'] == "Kanemaru 2023:D7", 'donor_id'] = "Kanemaru 2023:D7-Nuclei_Multiome-v1"
metadata_df.loc[metadata_df['donor_id'] == "Kanemaru 2023:D8", 'donor_id'] = "Kanemaru 2023:D8-Nuclei_Multiome-v1"
metadata_df.loc[metadata_df['donor_id'] == "Kanemaru 2023:AH1", 'donor_id'] = "Kanemaru 2023:AH1-Nuclei_Multiome-v1"

# %%
# examine intersection between RNA and ATAC 
set(metadata_df['donor_id']) & RNA_donors
# Out:
# {'Kanemaru 2023:AH1-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D3-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D7-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D8-Nuclei_Multiome-v1',
#  'Kuppe 2022:P1',
#  'Kuppe 2022:P10',
#  'Kuppe 2022:P11',
#  'Kuppe 2022:P12',
#  'Kuppe 2022:P14',
#  'Kuppe 2022:P15',
#  'Kuppe 2022:P17',
#  'Kuppe 2022:P18',
#  'Kuppe 2022:P19',
#  'Kuppe 2022:P2',
#  'Kuppe 2022:P20',
#  'Kuppe 2022:P3',
#  'Kuppe 2022:P4',
#  'Kuppe 2022:P6',
#  'Kuppe 2022:P7',
#  'Kuppe 2022:P8',
#  'Kuppe 2022:P9',
#  'Penn:K1485',
#  'Penn:K1488',
#  'Penn:K1584',
#  'Penn:K1647',
#  'Penn:K1727',
#  'Penn:ND15755',
#  'Penn:Penn_F1',
#  'Penn:Penn_F2'}

# %% [markdown]
# #### It will be easier later if we use the ENCODE mapping file to change the names of the ENCODE donor_ids to their corresponding RNA donor_id

# %%
ENCODE_mapping_df = pd.read_csv("multiome_mapping_files/ENCODE_ATAC_RNA_mapping.txt", delim_whitespace=True)
ENCODE_mapping_df.head()
# Out:
#   RNA_directory_name Multiomic_series ATAC_directory_name age_status
# 0        ENCSR906MRL      ENCSR100UGC         ENCSR686FZG  Postnatal
# 1        ENCSR084XKX      ENCSR870POU         ENCSR320QOP  Postnatal
# 2        ENCSR352DXB      ENCSR573DJW         ENCSR161IHV  Postnatal
# 3        ENCSR237HWJ      ENCSR371YIY         ENCSR101LQQ  Postnatal
# 4        ENCSR485GOL      ENCSR323AMA         ENCSR912XZH  Postnatal

# %%
# add the study name so that the donor_ids can be mapped to each other
ENCODE_mapping_df['RNA_directory_name'] = "ENCODE v4 (Snyder):" + ENCODE_mapping_df['RNA_directory_name']
ENCODE_mapping_df['ATAC_directory_name'] = "ENCODE v4 (Snyder):" + ENCODE_mapping_df['ATAC_directory_name']

# %% [markdown]
# Now, change the ATAC metadata_df's donor_id to the RNA_directory_name

# %%
merged_metadata_df = metadata_df.merge(
    ENCODE_mapping_df[['ATAC_directory_name', 'RNA_directory_name']],  
    left_on='donor_id',                                         
    right_on='ATAC_directory_name',                             
    how='left'                                                  
)

# update donor_id with 'RNA_directory_name' if 'RNA_directory_name' is not NaN
merged_metadata_df['donor_id'] = merged_metadata_df['RNA_directory_name'].where(
    merged_metadata_df['RNA_directory_name'].notna(),  
    merged_metadata_df['donor_id']                     
)

# drop merged df columns no longer needed
merged_metadata_df = merged_metadata_df.drop(columns = ["ATAC_directory_name", "RNA_directory_name"])

# %%
# now examine the intersection
set(merged_metadata_df['donor_id']) & RNA_donors
# Out:
# {'ENCODE v4 (Snyder):ENCFF248EWR',
#  'ENCODE v4 (Snyder):ENCFF684YRB',
#  'ENCODE v4 (Snyder):ENCFF727JRO',
#  'ENCODE v4 (Snyder):ENCFF775ANN',
#  'ENCODE v4 (Snyder):ENCFF776DQR',
#  'ENCODE v4 (Snyder):ENCFF802AQC',
#  'ENCODE v4 (Snyder):ENCFF805YRY',
#  'ENCODE v4 (Snyder):ENCFF849ALE',
#  'ENCODE v4 (Snyder):ENCSR002SMQ',
#  'ENCODE v4 (Snyder):ENCSR008CVR',
#  'ENCODE v4 (Snyder):ENCSR012APQ',
#  'ENCODE v4 (Snyder):ENCSR056QLB',
#  'ENCODE v4 (Snyder):ENCSR067BOK',
#  'ENCODE v4 (Snyder):ENCSR076ZLE',
#  'ENCODE v4 (Snyder):ENCSR084XKX',
#  'ENCODE v4 (Snyder):ENCSR085XEW',
#  'ENCODE v4 (Snyder):ENCSR093GXF',
#  'ENCODE v4 (Snyder):ENCSR138JCM',
#  'ENCODE v4 (Snyder):ENCSR157FDD',
#  'ENCODE v4 (Snyder):ENCSR175TRJ',
#  'ENCODE v4 (Snyder):ENCSR176WWW',
#  'ENCODE v4 (Snyder):ENCSR190TRK',
#  'ENCODE v4 (Snyder):ENCSR203YOV',
#  'ENCODE v4 (Snyder):ENCSR204RHR',
#  'ENCODE v4 (Snyder):ENCSR231FNL',
#  'ENCODE v4 (Snyder):ENCSR237HWJ',
#  'ENCODE v4 (Snyder):ENCSR259VOY',
#  'ENCODE v4 (Snyder):ENCSR273JWD',
#  'ENCODE v4 (Snyder):ENCSR328GTN',
#  'ENCODE v4 (Snyder):ENCSR345CVL',
#  'ENCODE v4 (Snyder):ENCSR349AHE',
#  'ENCODE v4 (Snyder):ENCSR352DXB',
#  'ENCODE v4 (Snyder):ENCSR398YBK',
#  'ENCODE v4 (Snyder):ENCSR405YKM',
#  'ENCODE v4 (Snyder):ENCSR439ZVQ',
#  'ENCODE v4 (Snyder):ENCSR455MGH',
#  'ENCODE v4 (Snyder):ENCSR481QQR',
#  'ENCODE v4 (Snyder):ENCSR485GOL',
#  'ENCODE v4 (Snyder):ENCSR488UUT',
#  'ENCODE v4 (Snyder):ENCSR489URW',
#  'ENCODE v4 (Snyder):ENCSR540DHJ',
#  'ENCODE v4 (Snyder):ENCSR630LZS',
#  'ENCODE v4 (Snyder):ENCSR654MFX',
#  'ENCODE v4 (Snyder):ENCSR681GPY',
#  'ENCODE v4 (Snyder):ENCSR727OYO',
#  'ENCODE v4 (Snyder):ENCSR751BHQ',
#  'ENCODE v4 (Snyder):ENCSR753YOZ',
#  'ENCODE v4 (Snyder):ENCSR755CIF',
#  'ENCODE v4 (Snyder):ENCSR762LML',
#  'ENCODE v4 (Snyder):ENCSR763BII',
#  'ENCODE v4 (Snyder):ENCSR777RUZ',
#  'ENCODE v4 (Snyder):ENCSR788SNY',
#  'ENCODE v4 (Snyder):ENCSR801DHT',
#  'ENCODE v4 (Snyder):ENCSR814LMX',
#  'ENCODE v4 (Snyder):ENCSR851JBE',
#  'ENCODE v4 (Snyder):ENCSR899GYX',
#  'ENCODE v4 (Snyder):ENCSR906MRL',
#  'ENCODE v4 (Snyder):ENCSR919ENI',
#  'ENCODE v4 (Snyder):ENCSR962JKS',
#  'ENCODE v4 (Snyder):ENCSR980OCK',
#  'ENCODE v4 (Snyder):ENCSR991LHO',
#  'ENCODE v4 (Snyder):ENCSR994VEG',
#  'Kanemaru 2023:AH1-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D3-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D7-Nuclei_Multiome-v1',
#  'Kanemaru 2023:D8-Nuclei_Multiome-v1',
#  'Kuppe 2022:P1',
#  'Kuppe 2022:P10',
#  'Kuppe 2022:P11',
#  'Kuppe 2022:P12',
#  'Kuppe 2022:P14',
#  'Kuppe 2022:P15',
#  'Kuppe 2022:P17',
#  'Kuppe 2022:P18',
#  'Kuppe 2022:P19',
#  'Kuppe 2022:P2',
#  'Kuppe 2022:P20',
#  'Kuppe 2022:P3',
#  'Kuppe 2022:P4',
#  'Kuppe 2022:P6',
#  'Kuppe 2022:P7',
#  'Kuppe 2022:P8',
#  'Kuppe 2022:P9',
#  'Penn:K1485',
#  'Penn:K1488',
#  'Penn:K1584',
#  'Penn:K1647',
#  'Penn:K1727',
#  'Penn:ND15755',
#  'Penn:Penn_F1',
#  'Penn:Penn_F2'}

# %%
set(merged_metadata_df['donor_id']) - RNA_donors
# Out:
# {'Ameen 2022:GSM5495102_F6_v2',
#  'Ameen 2022:GSM5495103_F8_v2',
#  'Ameen 2022:GSM5495104_F19_v2',
#  'ENCODE v4 (Snyder):ENCFF069ATM',
#  'ENCODE v4 (Snyder):ENCSR080TZR',
#  'ENCODE v4 (Snyder):ENCSR277LDY',
#  'ENCODE v4 (Snyder):ENCSR288RQI',
#  'ENCODE v4 (Snyder):ENCSR409QLZ',
#  'ENCODE v4 (Snyder):ENCSR556UHL',
#  'ENCODE v4 (Snyder):ENCSR803QTN',
#  'ENCODE v4 (Snyder):ENCSR886PUY',
#  'ENCODE v4 (Snyder):ENCSR895LPX',
#  'ENCODE v4 (Snyder):ENCSR913OAS',
#  'Kuppe 2022:P5',
#  'Penn:Penn_F3',
#  'Penn:Penn_F4',
#  'Penn:Penn_F5'}

# %% [markdown]
# ### The non-intersecting donors are all accounted for:
#
# - Ameen 2022 only performed snATAC-seq
# - Penn F3 to F5 did not have corresponding RNA libraries
# - ENCFF069ATM did not have very many high quality snRNA-seq nuclei after QC filtering
# - There are 8 other ENCODE libraries for which only snATAC-seq was performed; they were NOT part of the Multiomics series
# - ENCSR409QLZ is part of the multiomic series, but the Multiomics Series: ENCSR519BTE is accessed denied
# - Kuppe P5 is the CAD,HF patient which we dropped as we cannot ascertain the patient's HF status

# %% [markdown]
# #### Based on this, we will drop the following patients that from the analysis as they lack a snRNA-seq correspondence or that snRNA-seq correspondence was removed: ENCODE v4 (Snyder):ENCSR409QLZ, Kuppe 2022:P5
#
# #### Before doing this, indicate the number of donors per study

# %%
merged_metadata_df[["study", "donor_id"]].drop_duplicates().groupby("study").count()
# Out:
#                     donor_id
# study
# Ameen 2022                 3
# ENCODE v4 (Snyder)        72
# Kanemaru 2023              4
# Kuppe 2022                18
# Penn                      11

# %% [markdown]
# Remove those 2 samples

# %%
remove_samples = ["ENCODE v4 (Snyder):ENCSR409QLZ", "Kuppe 2022:P5"]

filt_metadata_df = merged_metadata_df[~merged_metadata_df.donor_id.isin(remove_samples)].reset_index(drop=True).copy()

# drop the file_exists column
filt_metadata_df = filt_metadata_df.drop(columns = ["file_exists"])

# %%
len(set(filt_metadata_df.donor_id) & RNA_donors)
# Out:
# 91

# %%
len(set(filt_metadata_df.donor_id) - RNA_donors)
# Out:
# 15

# %%
len(RNA_donors - set(filt_metadata_df.donor_id))
# Out:
# 200

# %%
merged_metadata_df[["study", "technology", "donor_id"]].drop_duplicates().groupby(["study", "technology"]).count()
# Out:
#                                  donor_id
# study              technology
# Ameen 2022         10X_ATAC             3
# ENCODE v4 (Snyder) 10X_ATAC             8
#                    10X_Multiome        64
# Kanemaru 2023      10X_Multiome         4
# Kuppe 2022         10X_ATAC            18
# Penn               10X_ATAC            11

# %% [markdown]
# #### Therefore, there are 200 donors for which there is only RNA, 91 for which there are both RNA + ATAC, and 15 for which there are only ATAC

# %%
#RNA_donors - set(filt_metadata_df.donor_id)

# %% [markdown]
# ### Finally, inspect each study's metadata carefully one more time to confirm information

# %%
merged_metadata_df[merged_metadata_df['study'] == "Penn"].sort_values(by = "donor_id")
# Out:
#                  sample_id      donor_id study age_status   age     sex  \
# 5              K1485-run-1    Penn:K1485  Penn  Postnatal  78.0    male
# 6              K1485-run-2    Penn:K1485  Penn  Postnatal  78.0    male
# 7              K1488-run-1    Penn:K1488  Penn  Postnatal  81.0    male
# 8              K1488-run-2    Penn:K1488  Penn  Postnatal  81.0    male
# 9              K1584-run-1    Penn:K1584  Penn  Postnatal  22.0    male
# 10             K1584-run-2    Penn:K1584  Penn  Postnatal  22.0    male
# 11             K1647-run-1    Penn:K1647  Penn  Postnatal  34.0    male
# 12             K1647-run-2    Penn:K1647  Penn  Postnatal  34.0    male
# 13              K1727-LV-1    Penn:K1727  Penn  Postnatal  40.0    male
# 14              K1727-LV-2    Penn:K1727  Penn  Postnatal  40.0    male
# 16            NDRI15755_5k  Penn:ND15755  Penn  Postnatal  65.0    male
# 15           NDRI15755_10k  Penn:ND15755  Penn  Postnatal  65.0    male
# 113             Fetal-LV-2  Penn:Penn_F1  Penn      Fetal  18.0  female
# 114             Fetal-LV-1  Penn:Penn_F1  Penn      Fetal  18.0  female
# 110            Fetal-OFT-2  Penn:Penn_F2  Penn      Fetal  14.0    male
# 111            Fetal-LRV-1  Penn:Penn_F2  Penn      Fetal  14.0    male
# 115            Fetal-LRV-2  Penn:Penn_F2  Penn      Fetal  14.0    male
# 119            Fetal-OFT-1  Penn:Penn_F2  Penn      Fetal  14.0    male
# 118        Fetal-heart-8wk  Penn:Penn_F3  Penn      Fetal   8.0    male
# 112  Fetal-wholeHeart-10wk  Penn:Penn_F4  Penn      Fetal  10.0    male
# 116         Fetal-LRV-14wk  Penn:Penn_F5  Penn      Fetal  14.0    male
# 117         Fetal-OFT-14wk  Penn:Penn_F5  Penn      Fetal  14.0    male
#
#     region disease_binary technology                           fragment_file  \
# 5       LV              N   10X_ATAC         LV-K1485-run-1_fragments.tsv.gz
# 6       LV              N   10X_ATAC         LV-K1485-run-2_fragments.tsv.gz
# 7       LV              N   10X_ATAC         LV-K1488-run-1_fragments.tsv.gz
# 8       LV              N   10X_ATAC         LV-K1488-run-2_fragments.tsv.gz
# 9       LV              N   10X_ATAC         LV-K1584-run-1_fragments.tsv.gz
# 10      LV              N   10X_ATAC         LV-K1584-run-1_fragments.tsv.gz
# 11      LV              N   10X_ATAC         LV-K1647-run-1_fragments.tsv.gz
# 12      LV              N   10X_ATAC         LV-K1647-run-2_fragments.tsv.gz
# 13      LV              N   10X_ATAC             K1727-LV-1_fragments.tsv.gz
# 14      LV              N   10X_ATAC             K1727-LV-2_fragments.tsv.gz
# 16      LV              N   10X_ATAC        LV-NDRI15755_5k_fragments.tsv.gz
# 15      LV              N   10X_ATAC       LV-NDRI15755_10k_fragments.tsv.gz
# 113     LV              N   10X_ATAC             Fetal-LV-2_fragments.tsv.gz
# 114     LV              N   10X_ATAC             Fetal-LV-1_fragments.tsv.gz
# 110    OFT              N   10X_ATAC            Fetal-OFT-2_fragments.tsv.gz
# 111    LRV              N   10X_ATAC            Fetal-LRV-1_fragments.tsv.gz
# 115    LRV              N   10X_ATAC            Fetal-LRV-2_fragments.tsv.gz
# 119    OFT              N   10X_ATAC            Fetal-OFT-1_fragments.tsv.gz
# 118     WH              N   10X_ATAC        Fetal-heart-8wk_fragments.tsv.gz
# 112     WH              N   10X_ATAC  Fetal-wholeHeart-10wk_fragments.tsv.gz
# 116    LRV              N   10X_ATAC         Fetal-LRV-14wk_fragments.tsv.gz
# 117    OFT              N   10X_ATAC         Fetal-OFT-14wk_fragments.tsv.gz
#
#                                              full_path  file_exists
# 5    /mnt/data1/william/human_heart_project/Final_m...         True
# 6    /mnt/data1/william/human_heart_project/Final_m...         True
# 7    /mnt/data1/william/human_heart_project/Final_m...         True
# 8    /mnt/data1/william/human_heart_project/Final_m...         True
# 9    /mnt/data1/william/human_heart_project/Final_m...         True
# 10   /mnt/data1/william/human_heart_project/Final_m...         True
# 11   /mnt/data1/william/human_heart_project/Final_m...         True
# 12   /mnt/data1/william/human_heart_project/Final_m...         True
# 13   /mnt/data1/william/human_heart_project/Final_m...         True
# 14   /mnt/data1/william/human_heart_project/Final_m...         True
# 16   /mnt/data1/william/human_heart_project/Final_m...         True
# 15   /mnt/data1/william/human_heart_project/Final_m...         True
# 113  /mnt/data1/william/human_heart_project/Final_m...         True
# 114  /mnt/data1/william/human_heart_project/Final_m...         True
# 110  /mnt/data1/william/human_heart_project/Final_m...         True
# 111  /mnt/data1/william/human_heart_project/Final_m...         True
# 115  /mnt/data1/william/human_heart_project/Final_m...         True
# 119  /mnt/data1/william/human_heart_project/Final_m...         True
# 118  /mnt/data1/william/human_heart_project/Final_m...         True
# 112  /mnt/data1/william/human_heart_project/Final_m...         True
# 116  /mnt/data1/william/human_heart_project/Final_m...         True
# 117  /mnt/data1/william/human_heart_project/Final_m...         True

# %%
merged_metadata_df[merged_metadata_df['study'] == "Kuppe 2022"].sort_values(by = "donor_id")
# Out:
#           sample_id        donor_id       study age_status   age     sex  \
# 0    10X_ATAC_CK166   Kuppe 2022:P1  Kuppe 2022  Postnatal  44.0    male
# 94   10X_ATAC_CK341  Kuppe 2022:P10  Kuppe 2022  Postnatal  38.0    male
# 103  10X_ATAC_CK380  Kuppe 2022:P11  Kuppe 2022  Postnatal  60.0  female
# 87   10X_ATAC_CK385  Kuppe 2022:P12  Kuppe 2022  Postnatal  40.0    male
# 105  10X_ATAC_CK346  Kuppe 2022:P14  Kuppe 2022  Postnatal  59.0    male
# 109  10X_ATAC_CK387  Kuppe 2022:P14  Kuppe 2022  Postnatal  59.0    male
# 106  10X_ATAC_CK352  Kuppe 2022:P15  Kuppe 2022  Postnatal  43.0  female
# 108  10X_ATAC_CK350  Kuppe 2022:P15  Kuppe 2022  Postnatal  43.0  female
# 4    10X_ATAC_CK381  Kuppe 2022:P17  Kuppe 2022  Postnatal  61.0    male
# 3    10X_ATAC_CK353  Kuppe 2022:P17  Kuppe 2022  Postnatal  61.0    male
# 89   10X_ATAC_CK388  Kuppe 2022:P18  Kuppe 2022  Postnatal  64.0  female
# 92   10X_ATAC_CK389  Kuppe 2022:P19  Kuppe 2022  Postnatal  58.0    male
# 95   10X_ATAC_CK171   Kuppe 2022:P2  Kuppe 2022  Postnatal  44.0    male
# 97   10X_ATAC_CK174   Kuppe 2022:P2  Kuppe 2022  Postnatal  44.0    male
# 98   10X_ATAC_CK382  Kuppe 2022:P20  Kuppe 2022  Postnatal  63.0    male
# 90   10X_ATAC_CK349  Kuppe 2022:P20  Kuppe 2022  Postnatal  63.0    male
# 93   10X_ATAC_CK168   Kuppe 2022:P3  Kuppe 2022  Postnatal  57.0    male
# 102  10X_ATAC_CK173   Kuppe 2022:P3  Kuppe 2022  Postnatal  57.0    male
# 104  10X_ATAC_CK170   Kuppe 2022:P4  Kuppe 2022  Postnatal  74.0    male
# 91   10X_ATAC_CK167   Kuppe 2022:P5  Kuppe 2022  Postnatal  63.0    male
# 101  10X_ATAC_CK336   Kuppe 2022:P6  Kuppe 2022  Postnatal  47.0    male
# 1    10X_ATAC_CK337   Kuppe 2022:P7  Kuppe 2022  Postnatal  55.0  female
# 2    10X_ATAC_CK338   Kuppe 2022:P8  Kuppe 2022  Postnatal  44.0    male
# 99   10X_ATAC_CK383   Kuppe 2022:P9  Kuppe 2022  Postnatal  52.0  female
# 100  10X_ATAC_CK343   Kuppe 2022:P9  Kuppe 2022  Postnatal  52.0  female
# 107  10X_ATAC_CK354   Kuppe 2022:P9  Kuppe 2022  Postnatal  52.0  female
# 96   10X_ATAC_CK351   Kuppe 2022:P9  Kuppe 2022  Postnatal  52.0  female
# 88   10X_ATAC_CK340   Kuppe 2022:P9  Kuppe 2022  Postnatal  52.0  female
#
#     region disease_binary technology          fragment_file  \
# 0       LV              N   10X_ATAC  10X_ATAC_CK166.tsv.gz
# 94      IZ              Y   10X_ATAC  10X_ATAC_CK341.tsv.gz
# 103     RZ              Y   10X_ATAC  10X_ATAC_CK380.tsv.gz
# 87   RZ/BZ              Y   10X_ATAC  10X_ATAC_CK385.tsv.gz
# 105     FZ              Y   10X_ATAC  10X_ATAC_CK346.tsv.gz
# 109     FZ              Y   10X_ATAC  10X_ATAC_CK387.tsv.gz
# 106     IZ              Y   10X_ATAC  10X_ATAC_CK352.tsv.gz
# 108  GT/IZ              Y   10X_ATAC  10X_ATAC_CK350.tsv.gz
# 4       LV              N   10X_ATAC  10X_ATAC_CK381.tsv.gz
# 3       LV              N   10X_ATAC  10X_ATAC_CK353.tsv.gz
# 89      FZ              Y   10X_ATAC  10X_ATAC_CK388.tsv.gz
# 92   FZ/GT              Y   10X_ATAC  10X_ATAC_CK389.tsv.gz
# 95   RZ/BZ              Y   10X_ATAC  10X_ATAC_CK171.tsv.gz
# 97   IZ/BZ              Y   10X_ATAC  10X_ATAC_CK174.tsv.gz
# 98      FZ              Y   10X_ATAC  10X_ATAC_CK382.tsv.gz
# 90      FZ              Y   10X_ATAC  10X_ATAC_CK349.tsv.gz
# 93   RZ/BZ              Y   10X_ATAC  10X_ATAC_CK168.tsv.gz
# 102     RZ              Y   10X_ATAC  10X_ATAC_CK173.tsv.gz
# 104  FZ/GT              Y   10X_ATAC  10X_ATAC_CK170.tsv.gz
# 91   RZ/FZ              Y   10X_ATAC  10X_ATAC_CK167.tsv.gz
# 101     RZ              Y   10X_ATAC  10X_ATAC_CK336.tsv.gz
# 1       LV              N   10X_ATAC  10X_ATAC_CK337.tsv.gz
# 2       LV              N   10X_ATAC  10X_ATAC_CK338.tsv.gz
# 99   GT/IZ              Y   10X_ATAC  10X_ATAC_CK383.tsv.gz
# 100  GT/IZ              Y   10X_ATAC  10X_ATAC_CK343.tsv.gz
# 107  GT/IZ              Y   10X_ATAC  10X_ATAC_CK354.tsv.gz
# 96   GT/IZ              Y   10X_ATAC  10X_ATAC_CK351.tsv.gz
# 88      RZ              Y   10X_ATAC  10X_ATAC_CK340.tsv.gz
#
#                                              full_path  file_exists
# 0    /mnt/data1/william/human_heart_project/Final_m...         True
# 94   /mnt/data1/william/human_heart_project/Final_m...         True
# 103  /mnt/data1/william/human_heart_project/Final_m...         True
# 87   /mnt/data1/william/human_heart_project/Final_m...         True
# 105  /mnt/data1/william/human_heart_project/Final_m...         True
# 109  /mnt/data1/william/human_heart_project/Final_m...         True
# 106  /mnt/data1/william/human_heart_project/Final_m...         True
# 108  /mnt/data1/william/human_heart_project/Final_m...         True
# 4    /mnt/data1/william/human_heart_project/Final_m...         True
# 3    /mnt/data1/william/human_heart_project/Final_m...         True
# 89   /mnt/data1/william/human_heart_project/Final_m...         True
# 92   /mnt/data1/william/human_heart_project/Final_m...         True
# 95   /mnt/data1/william/human_heart_project/Final_m...         True
# 97   /mnt/data1/william/human_heart_project/Final_m...         True
# 98   /mnt/data1/william/human_heart_project/Final_m...         True
# 90   /mnt/data1/william/human_heart_project/Final_m...         True
# 93   /mnt/data1/william/human_heart_project/Final_m...         True
# 102  /mnt/data1/william/human_heart_project/Final_m...         True
# 104  /mnt/data1/william/human_heart_project/Final_m...         True
# 91   /mnt/data1/william/human_heart_project/Final_m...         True
# 101  /mnt/data1/william/human_heart_project/Final_m...         True
# 1    /mnt/data1/william/human_heart_project/Final_m...         True
# 2    /mnt/data1/william/human_heart_project/Final_m...         True
# 99   /mnt/data1/william/human_heart_project/Final_m...         True
# 100  /mnt/data1/william/human_heart_project/Final_m...         True
# 107  /mnt/data1/william/human_heart_project/Final_m...         True
# 96   /mnt/data1/william/human_heart_project/Final_m...         True
# 88   /mnt/data1/william/human_heart_project/Final_m...         True

# %%
merged_metadata_df[merged_metadata_df['study'] == "Ameen 2022"].sort_values(by = "donor_id")
# Out:
#              sample_id                      donor_id       study age_status  \
# 121   GSM5495102_F6_v2   Ameen 2022:GSM5495102_F6_v2  Ameen 2022      Fetal
# 120   GSM5495103_F8_v2   Ameen 2022:GSM5495103_F8_v2  Ameen 2022      Fetal
# 122  GSM5495104_F19_v2  Ameen 2022:GSM5495104_F19_v2  Ameen 2022      Fetal
#
#       age     sex region disease_binary technology  \
# 121   6.0  female     WH              N   10X_ATAC
# 120   8.0    male     WH              N   10X_ATAC
# 122  19.0  female     WH              N   10X_ATAC
#
#                           fragment_file  \
# 121   GSM5495102_F6_v2_fragments.tsv.gz
# 120   GSM5495103_F8_v2_fragments.tsv.gz
# 122  GSM5495104_F19_v2_fragments.tsv.gz
#
#                                              full_path  file_exists
# 121  /mnt/data1/william/human_heart_project/Final_m...         True
# 120  /mnt/data1/william/human_heart_project/Final_m...         True
# 122  /mnt/data1/william/human_heart_project/Final_m...         True

# %%
merged_metadata_df[merged_metadata_df['study'] == "Kanemaru 2023"].sort_values(by = "donor_id")
# Out:
#                                 sample_id  \
# 20  HCAHeartST10773165_HCAHeartST10781062
# 21  HCAHeartST10773166_HCAHeartST10781063
# 22  HCAHeartST11064574_HCAHeartST11023239
# 23  HCAHeartST11064575_HCAHeartST11023240
# 17        HCAHeart9508627_HCAHeart9508819
# 18        HCAHeart9508629_HCAHeart9508821
# 19        HCAHeart9845431_HCAHeart9917173
#
#                                 donor_id          study age_status   age  \
# 20  Kanemaru 2023:AH1-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  47.5
# 21  Kanemaru 2023:AH1-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  47.5
# 22  Kanemaru 2023:AH1-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  47.5
# 23  Kanemaru 2023:AH1-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  47.5
# 17   Kanemaru 2023:D3-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  57.5
# 18   Kanemaru 2023:D7-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  62.5
# 19   Kanemaru 2023:D8-Nuclei_Multiome-v1  Kanemaru 2023  Postnatal  47.5
#
#        sex region disease_binary    technology  \
# 20  female     LV              N  10X_Multiome
# 21  female     LV              N  10X_Multiome
# 22  female     LV              N  10X_Multiome
# 23  female     LV              N  10X_Multiome
# 17    male     LV              N  10X_Multiome
# 18    male     LV              N  10X_Multiome
# 19    male     LV              N  10X_Multiome
#
#                                         fragment_file  \
# 20  HCAHeartST10773165_HCAHeartST10781062_fragment...
# 21  HCAHeartST10773166_HCAHeartST10781063_fragment...
# 22  HCAHeartST11064574_HCAHeartST11023239_fragment...
# 23  HCAHeartST11064575_HCAHeartST11023240_fragment...
# 17   HCAHeart9508627_HCAHeart9508819_fragments.tsv.gz
# 18   HCAHeart9508629_HCAHeart9508821_fragments.tsv.gz
# 19   HCAHeart9845431_HCAHeart9917173_fragments.tsv.gz
#
#                                             full_path  file_exists
# 20  /mnt/data1/william/human_heart_project/Final_m...         True
# 21  /mnt/data1/william/human_heart_project/Final_m...         True
# 22  /mnt/data1/william/human_heart_project/Final_m...         True
# 23  /mnt/data1/william/human_heart_project/Final_m...         True
# 17  /mnt/data1/william/human_heart_project/Final_m...         True
# 18  /mnt/data1/william/human_heart_project/Final_m...         True
# 19  /mnt/data1/william/human_heart_project/Final_m...         True

# %%
merged_metadata_df[merged_metadata_df['study'] == "ENCODE v4 (Snyder)"].sort_values(by = "donor_id")
# Out:
#        sample_id                        donor_id               study  \
# 127  ENCFF575DGZ  ENCODE v4 (Snyder):ENCFF069ATM  ENCODE v4 (Snyder)
# 131  ENCFF908JHS  ENCODE v4 (Snyder):ENCFF248EWR  ENCODE v4 (Snyder)
# 125  ENCFF658TEH  ENCODE v4 (Snyder):ENCFF684YRB  ENCODE v4 (Snyder)
# 124  ENCFF904ARJ  ENCODE v4 (Snyder):ENCFF727JRO  ENCODE v4 (Snyder)
# 128  ENCFF851VTB  ENCODE v4 (Snyder):ENCFF775ANN  ENCODE v4 (Snyder)
# ..           ...                             ...                 ...
# 56   ENCSR769WLL  ENCODE v4 (Snyder):ENCSR919ENI  ENCODE v4 (Snyder)
# 71   ENCSR020FAW  ENCODE v4 (Snyder):ENCSR962JKS  ENCODE v4 (Snyder)
# 68   ENCSR546WZB  ENCODE v4 (Snyder):ENCSR980OCK  ENCODE v4 (Snyder)
# 48   ENCSR173UUN  ENCODE v4 (Snyder):ENCSR991LHO  ENCODE v4 (Snyder)
# 42   ENCSR951AID  ENCODE v4 (Snyder):ENCSR994VEG  ENCODE v4 (Snyder)
#
#     age_status   age     sex region disease_binary    technology  \
# 127      Fetal   8.0    male     WH              N  10X_Multiome
# 131      Fetal  15.0    male     WH              N  10X_Multiome
# 125      Fetal  10.0  female     WH              N  10X_Multiome
# 124      Fetal  17.0  female     WH              N  10X_Multiome
# 128      Fetal  15.0  female     WH              N  10X_Multiome
# ..         ...   ...     ...    ...            ...           ...
# 56   Postnatal  51.0    male     LV              N  10X_Multiome
# 71   Postnatal  21.0    male     LV              N  10X_Multiome
# 68   Postnatal  47.0  female     LV              N  10X_Multiome
# 48   Postnatal  65.0    male     LV              N  10X_Multiome
# 42   Postnatal  51.0  female     LV              N  10X_Multiome
#
#                     fragment_file  \
# 127  ENCFF575DGZ_fragments.tsv.gz
# 131  ENCFF908JHS_fragments.tsv.gz
# 125  ENCFF658TEH_fragments.tsv.gz
# 124  ENCFF904ARJ_fragments.tsv.gz
# 128  ENCFF851VTB_fragments.tsv.gz
# ..                            ...
# 56   ENCSR769WLL_fragments.tsv.gz
# 71   ENCSR020FAW_fragments.tsv.gz
# 68   ENCSR546WZB_fragments.tsv.gz
# 48   ENCSR173UUN_fragments.tsv.gz
# 42   ENCSR951AID_fragments.tsv.gz
#
#                                              full_path  file_exists
# 127  /mnt/data1/william/human_heart_project/Final_m...         True
# 131  /mnt/data1/william/human_heart_project/Final_m...         True
# 125  /mnt/data1/william/human_heart_project/Final_m...         True
# 124  /mnt/data1/william/human_heart_project/Final_m...         True
# 128  /mnt/data1/william/human_heart_project/Final_m...         True
# ..                                                 ...          ...
# 56   /mnt/data1/william/human_heart_project/Final_m...         True
# 71   /mnt/data1/william/human_heart_project/Final_m...         True
# 68   /mnt/data1/william/human_heart_project/Final_m...         True
# 48   /mnt/data1/william/human_heart_project/Final_m...         True
# 42   /mnt/data1/william/human_heart_project/Final_m...         True
#
# [72 rows x 12 columns]

# %% [markdown]
# ### Save this updated metadata

# %%
filt_metadata_df.head()
# Out:
#         sample_id        donor_id       study age_status   age     sex region  \
# 0  10X_ATAC_CK166   Kuppe 2022:P1  Kuppe 2022  Postnatal  44.0    male     LV
# 1  10X_ATAC_CK337   Kuppe 2022:P7  Kuppe 2022  Postnatal  55.0  female     LV
# 2  10X_ATAC_CK338   Kuppe 2022:P8  Kuppe 2022  Postnatal  44.0    male     LV
# 3  10X_ATAC_CK353  Kuppe 2022:P17  Kuppe 2022  Postnatal  61.0    male     LV
# 4  10X_ATAC_CK381  Kuppe 2022:P17  Kuppe 2022  Postnatal  61.0    male     LV
#
#   disease_binary technology          fragment_file  \
# 0              N   10X_ATAC  10X_ATAC_CK166.tsv.gz
# 1              N   10X_ATAC  10X_ATAC_CK337.tsv.gz
# 2              N   10X_ATAC  10X_ATAC_CK338.tsv.gz
# 3              N   10X_ATAC  10X_ATAC_CK353.tsv.gz
# 4              N   10X_ATAC  10X_ATAC_CK381.tsv.gz
#
#                                            full_path
# 0  /mnt/data1/william/human_heart_project/Final_m...
# 1  /mnt/data1/william/human_heart_project/Final_m...
# 2  /mnt/data1/william/human_heart_project/Final_m...
# 3  /mnt/data1/william/human_heart_project/Final_m...
# 4  /mnt/data1/william/human_heart_project/Final_m...

# %%
filt_metadata_df.to_csv("00_updated_metadata.csv")
