# %%
import pandas as pd
import numpy as np
import os

# %%
metadata = pd.read_csv("02_full_metadata.txt", delim_whitespace = True)
metadata
# Out:
#                    sample                                               path  \
# 0         Fetal-heart-8wk       Fetal-heart-8wk/counts/outs/fragments.tsv.gz
# 1             Fetal-LRV-1           Fetal-LRV-1/counts/outs/fragments.tsv.gz
# 2          Fetal-LRV-14wk        Fetal-LRV-14wk/counts/outs/fragments.tsv.gz
# 3             Fetal-LRV-2           Fetal-LRV-2/counts/outs/fragments.tsv.gz
# 4              Fetal-LV-1            Fetal-LV-1/counts/outs/fragments.tsv.gz
# 5              Fetal-LV-2            Fetal-LV-2/counts/outs/fragments.tsv.gz
# 6             Fetal-OFT-1           Fetal-OFT-1/counts/outs/fragments.tsv.gz
# 7          Fetal-OFT-14wk        Fetal-OFT-14wk/counts/outs/fragments.tsv.gz
# 8             Fetal-OFT-2           Fetal-OFT-2/counts/outs/fragments.tsv.gz
# 9   Fetal-wholeHeart-10wk  Fetal-wholeHeart-10wk/counts/outs/fragments.ts...
# 10             H7CM-D20-1            H7CM-D20-1/counts/outs/fragments.tsv.gz
# ...

# %%
current_dir = os.getcwd() + "/"
current_dir
# Out:
# '/mnt/data1/william/human_heart_project/in_house_data/raw_data/ATAC/'

# %% [markdown]
# ### Confirm that the fragment paths exist

# %%
fragment_paths = current_dir + metadata['path']

# %%
[os.path.exists(frag) for frag in fragment_paths]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]
